# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates,
)

damage_file = "Damage_cost_curves.tab"
protection_file = "Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# --- 1) Load cost curves ---
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# --- 2) Prune candidates ---
start_year, end_year = years_range
n_years = end_year - start_year + 1

candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)

print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# --- 3) Load predictive posterior + future MSL paths from NPZ ---
pp = np.load("pp_inputs_halmsdad_pp_mixture_2025_2100.npz")

# Posterior draws (flattened)
eta0_s   = pp["eta0"].reshape(-1)
eta1_s   = pp["eta1"].reshape(-1)
alpha0_s = pp["alpha0"].reshape(-1)
xi_s     = pp["xi"].reshape(-1)
u_cm     = float(pp["u"])  # threshold in cm, if you want to store/pass it

posterior_params = {
    "eta0": eta0_s,
    "eta1": eta1_s,
    "alpha0": alpha0_s,
    "xi": xi_s,
    # Optional: if you want run_bandit_from_candidates to pick it up:
    "u": u_cm,
}

# Future MSL information (already in cm)
years_future   = pp["years_future"]      # shape (T_future,)
X_future_paths = pp["X_future_paths"]    # shape (M_pred, T_future), in cm

# --- 4) Run the bandit on the pruned candidate set ---
rng = np.random.default_rng(42)

best_height, history = run_bandit_from_candidates(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=100000,
    rng=rng,
    verbose=True,
)

best_height
# Out:
# Round 1000: best height 2.00 m, mean cost 269.673, r=28349.362, separated=False
# Round 2000: best height 2.00 m, mean cost 271.483, r=20705.403, separated=False
# Round 3000: best height 2.00 m, mean cost 267.833, r=17213.065, separated=False
# Round 4000: best height 2.00 m, mean cost 266.639, r=15092.864, separated=False
# Round 5000: best height 2.00 m, mean cost 267.499, r=13627.056, separated=False
# Round 6000: best height 2.00 m, mean cost 269.154, r=12534.105, separated=False
# Round 7000: best height 2.00 m, mean cost 267.402, r=11677.682, separated=False
# Round 8000: best height 2.00 m, mean cost 266.897, r=10982.564, separated=False
# Round 9000: best height 2.00 m, mean cost 266.412, r=10403.357, separated=False
# Round 10000: best height 2.00 m, mean cost 264.953, r=9910.801, separated=False
# Round 11000: best height 2.00 m, mean cost 264.059, r=9485.068, separated=False
# Round 12000: best height 2.00 m, mean cost 264.339, r=9112.171, separated=False
# Round 13000: best height 2.00 m, mean cost 263.387, r=8781.921, separated=False
# Round 14000: best height 2.00 m, mean cost 263.633, r=8486.693, separated=False
# Round 15000: best height 2.00 m, mean cost 262.186, r=8220.650, separated=False
# Round 16000: best height 2.00 m, mean cost 265.140, r=7979.238, separated=False
# Round 17000: best height 2.00 m, mean cost 266.384, r=7758.842, separated=False
# Round 18000: best height 2.00 m, mean cost 266.832, r=7556.553, separated=False
# Round 19000: best height 2.00 m, mean cost 267.962, r=7369.996, separated=False
# Round 20000: best height 2.00 m, mean cost 266.868, r=7197.216, separated=False
# Round 21000: best height 2.00 m, mean cost 269.989, r=7036.579, separated=False
# Round 22000: best height 2.00 m, mean cost 271.892, r=6886.714, separated=False
# Round 23000: best height 2.00 m, mean cost 271.563, r=6746.458, separated=False
# Round 24000: best height 2.00 m, mean cost 270.719, r=6614.816, separated=False
# Round 25000: best height 2.00 m, mean cost 270.700, r=6490.932, separated=False
# Round 26000: best height 2.00 m, mean cost 270.974, r=6374.067, separated=False
# Round 27000: best height 2.00 m, mean cost 272.290, r=6263.575, separated=False
# Round 28000: best height 2.00 m, mean cost 272.054, r=6158.892, separated=False
# Round 29000: best height 2.00 m, mean cost 272.377, r=6059.521, separated=False
# Round 30000: best height 2.00 m, mean cost 271.851, r=5965.024, separated=False
# Round 31000: best height 2.00 m, mean cost 271.401, r=5875.012, separated=False
# Round 32000: best height 2.00 m, mean cost 270.838, r=5789.136, separated=False
# Round 33000: best height 2.00 m, mean cost 270.725, r=5707.087, separated=False
# Round 34000: best height 2.00 m, mean cost 270.495, r=5628.585, separated=False
# Round 35000: best height 2.00 m, mean cost 271.440, r=5553.381, separated=False
# Round 36000: best height 2.00 m, mean cost 270.854, r=5481.246, separated=False
# Round 37000: best height 2.00 m, mean cost 270.403, r=5411.977, separated=False
# Round 38000: best height 2.00 m, mean cost 269.856, r=5345.385, separated=False
# Round 39000: best height 2.00 m, mean cost 269.938, r=5281.303, separated=False
# Round 40000: best height 2.00 m, mean cost 270.081, r=5219.573, separated=False
# Round 41000: best height 2.00 m, mean cost 270.006, r=5160.055, separated=False
# Round 42000: best height 2.00 m, mean cost 270.013, r=5102.618, separated=False
# Round 43000: best height 2.00 m, mean cost 270.191, r=5047.143, separated=False
# Round 44000: best height 2.00 m, mean cost 270.976, r=4993.518, separated=False
# Round 45000: best height 2.00 m, mean cost 270.709, r=4941.644, separated=False
# Round 46000: best height 2.00 m, mean cost 270.564, r=4891.425, separated=False
# Round 47000: best height 2.00 m, mean cost 270.298, r=4842.774, separated=False
# Round 48000: best height 2.00 m, mean cost 270.973, r=4795.611, separated=False
# Round 49000: best height 2.00 m, mean cost 270.959, r=4749.861, separated=False
# Round 50000: best height 2.00 m, mean cost 270.648, r=4705.453, separated=False
# Round 51000: best height 2.00 m, mean cost 271.234, r=4662.324, separated=False
# Round 52000: best height 2.00 m, mean cost 271.060, r=4620.412, separated=False
# Round 53000: best height 2.00 m, mean cost 270.739, r=4579.659, separated=False
# Round 54000: best height 2.00 m, mean cost 271.991, r=4540.015, separated=False
# Round 55000: best height 2.00 m, mean cost 272.262, r=4501.428, separated=False
# Round 56000: best height 2.00 m, mean cost 272.053, r=4463.851, separated=False
# Round 57000: best height 2.00 m, mean cost 272.397, r=4427.242, separated=False
# Round 58000: best height 2.00 m, mean cost 272.493, r=4391.559, separated=False
# Round 59000: best height 2.00 m, mean cost 272.503, r=4356.763, separated=False
# Round 60000: best height 2.00 m, mean cost 272.781, r=4322.818, separated=False
# Round 61000: best height 2.00 m, mean cost 272.445, r=4289.689, separated=False
# Round 62000: best height 2.00 m, mean cost 272.279, r=4257.344, separated=False
# Round 63000: best height 2.00 m, mean cost 272.221, r=4225.751, separated=False
# Round 64000: best height 2.00 m, mean cost 272.015, r=4194.883, separated=False
# Round 65000: best height 2.00 m, mean cost 272.398, r=4164.711, separated=False
# Round 66000: best height 2.00 m, mean cost 272.316, r=4135.210, separated=False
# Round 67000: best height 2.00 m, mean cost 273.856, r=4106.354, separated=False
# Round 68000: best height 2.00 m, mean cost 274.272, r=4078.121, separated=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      24 # --- 4) Run the bandit on the pruned candidate set ---
#      25 rng = np.random.default_rng(42)
# ---> 27 best_height, history = run_bandit_from_candidates(
#      28     heights=heights,
#      29     damage_costs=damage_costs,
#      30     protection_costs=protection_costs,
#      31     candidate_indices=candidate_indices,
#      32     years_all=years_future,
#      33     X_pred_paths_cm=X_future_paths,
#      34     posterior_params=posterior_params,
#      35     years_range=years_range,
#      36     delta=0.05,
#      37     max_rounds=100000,
#      38     rng=rng,
#      39     verbose=True,
#      40 )
#      42 best_height
#
# File c:\Users\johan\OneDrive\Skrivbord\Python_vscode\flood_bandit\optimal_levee_bandit.py:819, in run_bandit_from_candidates(heights, damage_costs, protection_costs, candidate_indices, years_all, X_pred_paths_cm, posterior_params, years_range, delta, max_rounds, rng, verbose)
#     816 X_t_series_cm = X_paths_slice_cm[m]  # shape (n_years,)
#     818 # Simulate annual maxima in cm, then convert to metres
# --> 819 maxima_cm = simulate_annual_max_pp(
#     820     eta0=eta0,
#     821     eta1=eta1,
#     822     alpha0=alpha0,
#     823     xi=xi,
#     824     X_t_series_cm=X_t_series_cm,
#     825     u_cm=u_cm,
#     826     rng=rng,
#     827 )
#     828 maxima_m = maxima_cm / 100.0  # cm → m, shape (n_years,)
#     830 # --- Accumulate damage for all candidates (vectorised) ---
#     831 # exceedances: shape (C, n_years)
#
# File c:\Users\johan\OneDrive\Skrivbord\Python_vscode\flood_bandit\optimal_levee_bandit.py:461, in simulate_annual_max_pp(eta0, eta1, alpha0, xi, X_t_series_cm, u_cm, rng)
#     458         else:
#     459             # Inverse CDF for GPD: z = σ/ξ * ((1 - U)^(-ξ) - 1)
#     460             Z = sigma / xi * ((1.0 - U) ** (-xi) - 1.0)
# --> 461         maxima_cm[j] = u_cm + Z.max()
#     463 return maxima_cm
#
# File c:\Users\johan\miniconda3\envs\flood_pymc\Lib\site-packages\numpy\_core\_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      35     _complex_to_float.update({
#      36         nt.dtype(nt.clongdouble): nt.dtype(nt.longdouble),
#      37     })
#      39 # avoid keyword arguments to speed up parsing, saves about 15%-20% for very
#      40 # small reductions
# ---> 41 def _amax(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
#      43     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      45 def _amin(a, axis=None, out=None, keepdims=False,
#      46           initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates_eff,  # our new efficient function
)

damage_file = "Damage_cost_curves.tab"
protection_file = "Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# 1. Load cost curves
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# 2. Prune deterministically dominated heights
start_year, end_year = years_range
n_years = end_year - start_year + 1
candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)
print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# 3. Load predictive posterior and future MSL paths from your NPZ
pp = np.load("pp_inputs_halmsdad_pp_mixture_2025_2100.npz")
posterior_params = {
    "eta0": pp["eta0"],
    "eta1": pp["eta1"],
    "alpha0": pp["alpha0"],
    "xi": pp["xi"],
    "u": float(pp["u"]),  # optional threshold (cm)
}
years_future   = pp["years_future"]
X_future_paths = pp["X_future_paths"]  # already in cm

# 4. Run the efficient bandit
rng = np.random.default_rng(42)
best_height, history = run_bandit_from_candidates_eff(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=10000000,
    rng=rng,
    verbose=True,
)

print(f"Selected design height: {best_height:.2f} m")
# Out:
# Round 1000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.051
#   height = 0.50 m, mean total cost = 1084.226
#   height = 1.00 m, mean total cost = 541.566
#   height = 1.50 m, mean total cost = 312.281
#   height = 2.00 m, mean total cost = 278.457
#   height = 2.50 m, mean total cost = 324.308
#   height = 3.00 m, mean total cost = 409.154
#   height = 3.50 m, mean total cost = 521.720
#   height = 4.00 m, mean total cost = 664.579
#   height = 4.50 m, mean total cost = 826.368
#   height = 5.00 m, mean total cost = 1005.749
#   height = 5.50 m, mean total cost = 1209.485
#   height = 6.00 m, mean total cost = 1433.204
#   height = 6.50 m, mean total cost = 1687.953
#   height = 7.00 m, mean total cost = 1955.378
#   height = 7.50 m, mean total cost = 2235.050
#   height = 8.00 m, mean total cost = 2526.536
#   height = 8.50 m, mean total cost = 2842.247
#   height = 9.00 m, mean total cost = 3167.366
#   height = 9.50 m, mean total cost = 3510.522
#   height = 10.00 m, mean total cost = 3869.005
#   height = 10.50 m, mean total cost = 4253.030
#   height = 11.00 m, mean total cost = 4674.323
#   height = 11.50 m, mean total cost = 5122.481
#   height = 12.00 m, mean total cost = 5588.689
# Round 1000000: best height 2.00 m, mean cost 278.457, r=1157.330, separated=False
#
# Round 2000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.144
#   height = 0.50 m, mean total cost = 1084.368
#   height = 1.00 m, mean total cost = 541.747
#   height = 1.50 m, mean total cost = 312.487
#   height = 2.00 m, mean total cost = 278.692
#   height = 2.50 m, mean total cost = 324.571
#   height = 3.00 m, mean total cost = 409.445
#   height = 3.50 m, mean total cost = 522.034
#   height = 4.00 m, mean total cost = 664.912
#   height = 4.50 m, mean total cost = 826.714
#   height = 5.00 m, mean total cost = 1006.105
#   height = 5.50 m, mean total cost = 1209.848
#   height = 6.00 m, mean total cost = 1433.569
#   height = 6.50 m, mean total cost = 1688.315
#   height = 7.00 m, mean total cost = 1955.733
#   height = 7.50 m, mean total cost = 2235.400
#   height = 8.00 m, mean total cost = 2526.881
#   height = 8.50 m, mean total cost = 2842.586
#   height = 9.00 m, mean total cost = 3167.699
#   height = 9.50 m, mean total cost = 3510.854
#   height = 10.00 m, mean total cost = 3869.336
#   height = 10.50 m, mean total cost = 4253.363
#   height = 11.00 m, mean total cost = 4674.659
#   height = 11.50 m, mean total cost = 5122.817
#   height = 12.00 m, mean total cost = 5589.025
# Round 2000000: best height 2.00 m, mean cost 278.692, r=834.618, separated=False
#
# Round 3000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.919
#   height = 0.50 m, mean total cost = 1084.144
#   height = 1.00 m, mean total cost = 541.543
#   height = 1.50 m, mean total cost = 312.308
#   height = 2.00 m, mean total cost = 278.538
#   height = 2.50 m, mean total cost = 324.441
#   height = 3.00 m, mean total cost = 409.339
#   height = 3.50 m, mean total cost = 521.950
#   height = 4.00 m, mean total cost = 664.851
#   height = 4.50 m, mean total cost = 826.674
#   height = 5.00 m, mean total cost = 1006.085
#   height = 5.50 m, mean total cost = 1209.846
#   height = 6.00 m, mean total cost = 1433.579
#   height = 6.50 m, mean total cost = 1688.334
#   height = 7.00 m, mean total cost = 1955.758
#   height = 7.50 m, mean total cost = 2235.427
#   height = 8.00 m, mean total cost = 2526.906
#   height = 8.50 m, mean total cost = 2842.607
#   height = 9.00 m, mean total cost = 3167.717
#   height = 9.50 m, mean total cost = 3510.866
#   height = 10.00 m, mean total cost = 3869.344
#   height = 10.50 m, mean total cost = 4253.367
#   height = 11.00 m, mean total cost = 4674.659
#   height = 11.50 m, mean total cost = 5122.814
#   height = 12.00 m, mean total cost = 5589.019
# Round 3000000: best height 2.00 m, mean cost 278.538, r=689.111, separated=False
#
# Round 4000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.083
#   height = 0.50 m, mean total cost = 1084.261
#   height = 1.00 m, mean total cost = 541.621
#   height = 1.50 m, mean total cost = 312.355
#   height = 2.00 m, mean total cost = 278.553
#   height = 2.50 m, mean total cost = 324.429
#   height = 3.00 m, mean total cost = 409.311
#   height = 3.50 m, mean total cost = 521.914
#   height = 4.00 m, mean total cost = 664.813
#   height = 4.50 m, mean total cost = 826.636
#   height = 5.00 m, mean total cost = 1006.050
#   height = 5.50 m, mean total cost = 1209.814
#   height = 6.00 m, mean total cost = 1433.551
#   height = 6.50 m, mean total cost = 1688.309
#   height = 7.00 m, mean total cost = 1955.737
#   height = 7.50 m, mean total cost = 2235.411
#   height = 8.00 m, mean total cost = 2526.896
#   height = 8.50 m, mean total cost = 2842.603
#   height = 9.00 m, mean total cost = 3167.718
#   height = 9.50 m, mean total cost = 3510.873
#   height = 10.00 m, mean total cost = 3869.354
#   height = 10.50 m, mean total cost = 4253.380
#   height = 11.00 m, mean total cost = 4674.674
#   height = 11.50 m, mean total cost = 5122.831
#   height = 12.00 m, mean total cost = 5589.039
# Round 4000000: best height 2.00 m, mean cost 278.553, r=601.443, separated=False
#
# Round 5000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.212
#   height = 0.50 m, mean total cost = 1084.453
#   height = 1.00 m, mean total cost = 541.856
#   height = 1.50 m, mean total cost = 312.624
#   height = 2.00 m, mean total cost = 278.843
#   height = 2.50 m, mean total cost = 324.721
#   height = 3.00 m, mean total cost = 409.596
#   height = 3.50 m, mean total cost = 522.189
#   height = 4.00 m, mean total cost = 665.077
#   height = 4.50 m, mean total cost = 826.891
#   height = 5.00 m, mean total cost = 1006.296
#   height = 5.50 m, mean total cost = 1210.052
#   height = 6.00 m, mean total cost = 1433.781
#   height = 6.50 m, mean total cost = 1688.532
#   height = 7.00 m, mean total cost = 1955.953
#   height = 7.50 m, mean total cost = 2235.621
#   height = 8.00 m, mean total cost = 2527.099
#   height = 8.50 m, mean total cost = 2842.800
#   height = 9.00 m, mean total cost = 3167.910
#   height = 9.50 m, mean total cost = 3511.060
#   height = 10.00 m, mean total cost = 3869.536
#   height = 10.50 m, mean total cost = 4253.558
#   height = 11.00 m, mean total cost = 4674.848
#   height = 11.50 m, mean total cost = 5123.001
#   height = 12.00 m, mean total cost = 5589.204
# Round 5000000: best height 2.00 m, mean cost 278.843, r=541.154, separated=False
#
# Round 6000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.032
#   height = 0.50 m, mean total cost = 1084.269
#   height = 1.00 m, mean total cost = 541.671
#   height = 1.50 m, mean total cost = 312.444
#   height = 2.00 m, mean total cost = 278.672
#   height = 2.50 m, mean total cost = 324.562
#   height = 3.00 m, mean total cost = 409.449
#   height = 3.50 m, mean total cost = 522.055
#   height = 4.00 m, mean total cost = 664.956
#   height = 4.50 m, mean total cost = 826.781
#   height = 5.00 m, mean total cost = 1006.197
#   height = 5.50 m, mean total cost = 1209.961
#   height = 6.00 m, mean total cost = 1433.697
#   height = 6.50 m, mean total cost = 1688.454
#   height = 7.00 m, mean total cost = 1955.880
#   height = 7.50 m, mean total cost = 2235.552
#   height = 8.00 m, mean total cost = 2527.034
#   height = 8.50 m, mean total cost = 2842.738
#   height = 9.00 m, mean total cost = 3167.851
#   height = 9.50 m, mean total cost = 3511.003
#   height = 10.00 m, mean total cost = 3869.483
#   height = 10.50 m, mean total cost = 4253.507
#   height = 11.00 m, mean total cost = 4674.800
#   height = 11.50 m, mean total cost = 5122.955
#   height = 12.00 m, mean total cost = 5589.160
# Round 6000000: best height 2.00 m, mean cost 278.672, r=496.384, separated=False
#
# Round 7000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.093
#   height = 0.50 m, mean total cost = 1084.308
#   height = 1.00 m, mean total cost = 541.691
#   height = 1.50 m, mean total cost = 312.448
#   height = 2.00 m, mean total cost = 278.667
#   height = 2.50 m, mean total cost = 324.550
#   height = 3.00 m, mean total cost = 409.432
#   height = 3.50 m, mean total cost = 522.032
#   height = 4.00 m, mean total cost = 664.929
#   height = 4.50 m, mean total cost = 826.752
#   height = 5.00 m, mean total cost = 1006.167
#   height = 5.50 m, mean total cost = 1209.931
#   height = 6.00 m, mean total cost = 1433.666
#   height = 6.50 m, mean total cost = 1688.423
#   height = 7.00 m, mean total cost = 1955.850
#   height = 7.50 m, mean total cost = 2235.523
#   height = 8.00 m, mean total cost = 2527.006
#   height = 8.50 m, mean total cost = 2842.712
#   height = 9.00 m, mean total cost = 3167.828
#   height = 9.50 m, mean total cost = 3510.982
#   height = 10.00 m, mean total cost = 3869.464
#   height = 10.50 m, mean total cost = 4253.490
#   height = 11.00 m, mean total cost = 4674.784
#   height = 11.50 m, mean total cost = 5122.940
#   height = 12.00 m, mean total cost = 5589.146
# Round 7000000: best height 2.00 m, mean cost 278.667, r=461.417, separated=False
#
# Round 8000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.770
#   height = 0.50 m, mean total cost = 1084.868
#   height = 1.00 m, mean total cost = 542.148
#   height = 1.50 m, mean total cost = 312.817
#   height = 2.00 m, mean total cost = 278.958
#   height = 2.50 m, mean total cost = 324.783
#   height = 3.00 m, mean total cost = 409.622
#   height = 3.50 m, mean total cost = 522.190
#   height = 4.00 m, mean total cost = 665.060
#   height = 4.50 m, mean total cost = 826.861
#   height = 5.00 m, mean total cost = 1006.258
#   height = 5.50 m, mean total cost = 1210.006
#   height = 6.00 m, mean total cost = 1433.729
#   height = 6.50 m, mean total cost = 1688.473
#   height = 7.00 m, mean total cost = 1955.890
#   height = 7.50 m, mean total cost = 2235.553
#   height = 8.00 m, mean total cost = 2527.029
#   height = 8.50 m, mean total cost = 2842.729
#   height = 9.00 m, mean total cost = 3167.838
#   height = 9.50 m, mean total cost = 3510.988
#   height = 10.00 m, mean total cost = 3869.466
#   height = 10.50 m, mean total cost = 4253.488
#   height = 11.00 m, mean total cost = 4674.779
#   height = 11.50 m, mean total cost = 5122.932
#   height = 12.00 m, mean total cost = 5589.135
# Round 8000000: best height 2.00 m, mean cost 278.958, r=433.113, separated=False
# c:\Users\johan\OneDrive\Skrivbord\Python_vscode\flood_bandit\optimal_levee_bandit.py:1010: RuntimeWarning: divide by zero encountered in power
#   (1.0 - U_max[large_mask]) ** (-xi_bt[large_mask]) - 1.0
# Round 9000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.765
#   height = 0.50 m, mean total cost = 1084.884
#   height = 1.00 m, mean total cost = 542.179
#   height = 1.50 m, mean total cost = 312.855
#   height = 2.00 m, mean total cost = 278.996
#   height = 2.50 m, mean total cost = 324.816
#   height = 3.00 m, mean total cost = 409.649
#   height = 3.50 m, mean total cost = 522.210
#   height = 4.00 m, mean total cost = 665.075
#   height = 4.50 m, mean total cost = 826.873
#   height = 5.00 m, mean total cost = 1006.267
#   height = 5.50 m, mean total cost = 1210.013
#   height = 6.00 m, mean total cost = 1433.734
#   height = 6.50 m, mean total cost = 1688.478
#   height = 7.00 m, mean total cost = 1955.895
#   height = 7.50 m, mean total cost = 2235.559
#   height = 8.00 m, mean total cost = 2527.035
#   height = 8.50 m, mean total cost = 2842.736
#   height = 9.00 m, mean total cost = 3167.846
#   height = 9.50 m, mean total cost = 3510.996
#   height = 10.00 m, mean total cost = 3869.473
#   height = 10.50 m, mean total cost = 4253.495
#   height = 11.00 m, mean total cost = 4674.786
#   height = 11.50 m, mean total cost = 5122.939
#   height = 12.00 m, mean total cost = 5589.141
# Round 9000000: best height 2.00 m, mean cost 278.996, r=409.584, separated=False
#
# Round 10000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.045
#   height = 0.50 m, mean total cost = 1085.119
#   height = 1.00 m, mean total cost = 542.377
#   height = 1.50 m, mean total cost = 313.019
#   height = 2.00 m, mean total cost = 279.135
#   height = 2.50 m, mean total cost = 324.936
#   height = 3.00 m, mean total cost = 409.754
#   height = 3.50 m, mean total cost = 522.303
#   height = 4.00 m, mean total cost = 665.158
#   height = 4.50 m, mean total cost = 826.948
#   height = 5.00 m, mean total cost = 1006.334
#   height = 5.50 m, mean total cost = 1210.074
#   height = 6.00 m, mean total cost = 1433.789
#   height = 6.50 m, mean total cost = 1688.527
#   height = 7.00 m, mean total cost = 1955.939
#   height = 7.50 m, mean total cost = 2235.598
#   height = 8.00 m, mean total cost = 2527.070
#   height = 8.50 m, mean total cost = 2842.767
#   height = 9.00 m, mean total cost = 3167.874
#   height = 9.50 m, mean total cost = 3511.021
#   height = 10.00 m, mean total cost = 3869.495
#   height = 10.50 m, mean total cost = 4253.514
#   height = 11.00 m, mean total cost = 4674.802
#   height = 11.50 m, mean total cost = 5122.952
#   height = 12.00 m, mean total cost = 5589.152
# Round 10000000: best height 2.00 m, mean cost 279.135, r=389.615, separated=False
# Selected design height: 2.00 m

# %%
import math
import numpy as np
delta=0.05
# --- Helper: required samples for a given assumed gap ---
def required_samples_for_gap(
    gap: float,
    D_max_total: float,
    num_cands: int,
    delta: float,
    S_max: int = 10**16,
) -> int:
    """
    Solve for S such that 2 * r(S) <= gap, where
    r(S) = D_max_total * sqrt( log(2 * K * S * (S + 1) / delta) / (2 S) ).
    """
    target = gap / 2.0  # need r(S) <= gap/2

    def radius(S: int) -> float:
        log_term = math.log(
            (2.0 * num_cands * S * (S + 1)) / max(delta, 1e-16)
        )
        return D_max_total * math.sqrt(log_term / (2.0 * S))

    # If S=1 already enough (unlikely), return 1
    if radius(1) <= target:
        return 1

    # Exponential search to bracket S
    low, high = 1, 1
    while high < S_max and radius(high) > target:
        low = high
        high *= 2

    if high >= S_max and radius(high) > target:
        # Could not find S within S_max
        return S_max

    # Binary search between low and high
    while low + 1 < high:
        mid = (low + high) // 2
        if radius(mid) <= target:
            high = mid
        else:
            low = mid

    return high


# --- Compute D_max_total and num_cands from your existing objects ---

# damage_costs: full damage curve (million EUR)
# years_range: (start_year, end_year)
# candidate_indices: indices of surviving heights
# delta: your bandit delta

start_year, end_year = years_range
n_years = end_year - start_year + 1
d_max = float(np.max(damage_costs))
D_max_total = n_years * d_max
num_cands = len(candidate_indices)

# --- Assume the gap between best & second best is about 30 ---
gap_assumed = 30.0

S_req = required_samples_for_gap(
    gap=gap_assumed,
    D_max_total=D_max_total,
    num_cands=num_cands,
    delta=delta,
)

print(f"Assumed gap = {gap_assumed:.1f}")
print(f"Approx. total samples needed for separation: {S_req}")
# Out:
# Assumed gap = 30.0
# Approx. total samples needed for separation: 9095155553

# %%
((9095155553/10000000)*(9*60))/(3600*24)
# Out:
# 5.684472220625
