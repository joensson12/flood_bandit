# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates,
)

damage_file = "data/Damage_cost_curves.tab"
protection_file = "data/Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# --- 1) Load cost curves ---
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# --- 2) Prune candidates ---
start_year, end_year = years_range
n_years = end_year - start_year + 1

candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)

print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# --- 3) Load predictive posterior + future MSL paths from NPZ ---
pp = np.load("data/pp_inputs_halmsdad_pp_mixture_2025_2100.npz")

# Posterior draws (flattened)
eta0_s   = pp["eta0"].reshape(-1)
eta1_s   = pp["eta1"].reshape(-1)
alpha0_s = pp["alpha0"].reshape(-1)
xi_s     = pp["xi"].reshape(-1)
u_cm     = float(pp["u"])  # threshold in cm, if you want to store/pass it

posterior_params = {
    "eta0": eta0_s,
    "eta1": eta1_s,
    "alpha0": alpha0_s,
    "xi": xi_s,
    # Optional: if you want run_bandit_from_candidates to pick it up:
    "u": u_cm,
}

# Future MSL information (already in cm)
years_future   = pp["years_future"]      # shape (T_future,)
X_future_paths = pp["X_future_paths"]    # shape (M_pred, T_future), in cm

# --- 4) Run the bandit on the pruned candidate set ---
rng = np.random.default_rng(42)

best_height, history = run_bandit_from_candidates(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=100000,
    rng=rng,
    verbose=True,
)

best_height
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 27
#      24 # --- 4) Run the bandit on the pruned candidate set ---
#      25 rng = np.random.default_rng(42)
# ---> 27 best_height, history = run_bandit_from_candidates(
#      28     heights=heights,
#      29     damage_costs=damage_costs,
#      30     protection_costs=protection_costs,
#      31     candidate_indices=candidate_indices,
#      32     years_all=years_future,
#      33     X_pred_paths_cm=X_future_paths,
#      34     posterior_params=posterior_params,
#      35     years_range=years_range,
#      36     delta=0.05,
#      37     max_rounds=100000,
#      38     rng=rng,
#      39     verbose=True,
#      40 )
#      42 best_height
#
# NameError: name 'run_bandit_from_candidates' is not defined

# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates_eff,  # our new efficient function
)

damage_file = "Damage_cost_curves.tab"
protection_file = "Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# 1. Load cost curves
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# 2. Prune deterministically dominated heights
start_year, end_year = years_range
n_years = end_year - start_year + 1
candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)
print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# 1. Load cost curves
damage_file = "data/Damage_cost_curves.tab"
protection_file = "data/Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# 2. Prune candidate set
start_year, end_year = years_range
n_years = end_year - start_year + 1
candidate_indices = prune_candidates(
    heights, protection_costs, damage_costs, n_years
)

# 3. Load predictive posterior and future MSL paths from your NPZ
pp = np.load("data/pp_inputs_halmsdad_pp_mixture_2025_2100.npz")
posterior_params = {
    "eta0": pp["eta0"],
    "eta1": pp["eta1"],
    "alpha0": pp["alpha0"],
    "xi": pp["xi"],
    "u": float(pp["u"]),  # optional threshold (cm)
}
years_future   = pp["years_future"]
X_future_paths = pp["X_future_paths"]  # already in cm

# 4. Run the efficient bandit
rng = np.random.default_rng(42)
best_height, history = run_bandit_from_candidates_eff(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=(4*5000000),
    rng=rng,
    verbose=True,
)

print(f"Selected design height: {best_height:.2f} m")
# Out:
# Round 1000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2046.086
#   height = 0.50 m, mean total cost = 2064.614
#   height = 1.00 m, mean total cost = 2032.506
#   height = 1.50 m, mean total cost = 1462.917
#   height = 2.00 m, mean total cost = 927.665
#   height = 2.50 m, mean total cost = 717.054
#   height = 3.00 m, mean total cost = 681.193
#   height = 3.50 m, mean total cost = 723.418
#   height = 4.00 m, mean total cost = 819.580
#   height = 4.50 m, mean total cost = 949.411
#   height = 5.00 m, mean total cost = 1105.418
#   height = 5.50 m, mean total cost = 1291.877
#   height = 6.00 m, mean total cost = 1502.358
#   height = 6.50 m, mean total cost = 1746.788
#   height = 7.00 m, mean total cost = 2005.798
#   height = 7.50 m, mean total cost = 2278.767
#   height = 8.00 m, mean total cost = 2564.772
#   height = 8.50 m, mean total cost = 2875.910
#   height = 9.00 m, mean total cost = 3197.165
#   height = 9.50 m, mean total cost = 3536.729
#   height = 10.00 m, mean total cost = 3892.026
#   height = 10.50 m, mean total cost = 4273.015
#   height = 11.00 m, mean total cost = 4691.942
#   height = 11.50 m, mean total cost = 5137.765
#   height = 12.00 m, mean total cost = 5601.904
# Round 1000000: best height 3.00 m, mean cost 681.193, r=1157.330, separated=False
#
# Round 2000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.906
#   height = 0.50 m, mean total cost = 2063.434
#   height = 1.00 m, mean total cost = 2031.364
#   height = 1.50 m, mean total cost = 1461.569
#   height = 2.00 m, mean total cost = 926.413
#   height = 2.50 m, mean total cost = 715.985
#   height = 3.00 m, mean total cost = 680.124
#   height = 3.50 m, mean total cost = 722.341
#   height = 4.00 m, mean total cost = 818.484
#   height = 4.50 m, mean total cost = 948.240
#   height = 5.00 m, mean total cost = 1104.326
#   height = 5.50 m, mean total cost = 1290.907
#   height = 6.00 m, mean total cost = 1501.429
#   height = 6.50 m, mean total cost = 1745.874
#   height = 7.00 m, mean total cost = 2004.949
#   height = 7.50 m, mean total cost = 2277.868
#   height = 8.00 m, mean total cost = 2563.857
#   height = 8.50 m, mean total cost = 2874.916
#   height = 9.00 m, mean total cost = 3196.163
#   height = 9.50 m, mean total cost = 3535.817
#   height = 10.00 m, mean total cost = 3891.260
#   height = 10.50 m, mean total cost = 4272.404
#   height = 11.00 m, mean total cost = 4691.266
#   height = 11.50 m, mean total cost = 5137.180
#   height = 12.00 m, mean total cost = 5601.400
# Round 2000000: best height 3.00 m, mean cost 680.124, r=834.618, separated=False
#
# Round 3000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.407
#   height = 0.50 m, mean total cost = 2062.935
#   height = 1.00 m, mean total cost = 2030.839
#   height = 1.50 m, mean total cost = 1461.144
#   height = 2.00 m, mean total cost = 926.093
#   height = 2.50 m, mean total cost = 715.504
#   height = 3.00 m, mean total cost = 679.575
#   height = 3.50 m, mean total cost = 721.735
#   height = 4.00 m, mean total cost = 817.914
#   height = 4.50 m, mean total cost = 947.736
#   height = 5.00 m, mean total cost = 1103.891
#   height = 5.50 m, mean total cost = 1290.465
#   height = 6.00 m, mean total cost = 1501.024
#   height = 6.50 m, mean total cost = 1745.572
#   height = 7.00 m, mean total cost = 2004.697
#   height = 7.50 m, mean total cost = 2277.674
#   height = 8.00 m, mean total cost = 2563.723
#   height = 8.50 m, mean total cost = 2874.813
#   height = 9.00 m, mean total cost = 3196.039
#   height = 9.50 m, mean total cost = 3535.694
#   height = 10.00 m, mean total cost = 3891.156
#   height = 10.50 m, mean total cost = 4272.316
#   height = 11.00 m, mean total cost = 4691.231
#   height = 11.50 m, mean total cost = 5137.152
#   height = 12.00 m, mean total cost = 5601.348
# Round 3000000: best height 3.00 m, mean cost 679.575, r=689.111, separated=False
#
# Round 4000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.184
#   height = 0.50 m, mean total cost = 2062.712
#   height = 1.00 m, mean total cost = 2030.604
#   height = 1.50 m, mean total cost = 1460.907
#   height = 2.00 m, mean total cost = 925.808
#   height = 2.50 m, mean total cost = 715.292
#   height = 3.00 m, mean total cost = 679.410
#   height = 3.50 m, mean total cost = 721.676
#   height = 4.00 m, mean total cost = 817.944
#   height = 4.50 m, mean total cost = 947.731
#   height = 5.00 m, mean total cost = 1103.955
#   height = 5.50 m, mean total cost = 1290.570
#   height = 6.00 m, mean total cost = 1501.181
#   height = 6.50 m, mean total cost = 1745.739
#   height = 7.00 m, mean total cost = 2004.918
#   height = 7.50 m, mean total cost = 2277.924
#   height = 8.00 m, mean total cost = 2564.003
#   height = 8.50 m, mean total cost = 2875.111
#   height = 9.00 m, mean total cost = 3196.348
#   height = 9.50 m, mean total cost = 3536.032
#   height = 10.00 m, mean total cost = 3891.484
#   height = 10.50 m, mean total cost = 4272.667
#   height = 11.00 m, mean total cost = 4691.536
#   height = 11.50 m, mean total cost = 5137.482
#   height = 12.00 m, mean total cost = 5601.610
# Round 4000000: best height 3.00 m, mean cost 679.410, r=601.443, separated=False
#
# Round 5000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.128
#   height = 0.50 m, mean total cost = 2062.656
#   height = 1.00 m, mean total cost = 2030.551
#   height = 1.50 m, mean total cost = 1460.792
#   height = 2.00 m, mean total cost = 925.717
#   height = 2.50 m, mean total cost = 715.267
#   height = 3.00 m, mean total cost = 679.425
#   height = 3.50 m, mean total cost = 721.720
#   height = 4.00 m, mean total cost = 818.006
#   height = 4.50 m, mean total cost = 947.798
#   height = 5.00 m, mean total cost = 1104.060
#   height = 5.50 m, mean total cost = 1290.729
#   height = 6.00 m, mean total cost = 1501.363
#   height = 6.50 m, mean total cost = 1745.937
#   height = 7.00 m, mean total cost = 2005.118
#   height = 7.50 m, mean total cost = 2278.116
#   height = 8.00 m, mean total cost = 2564.169
#   height = 8.50 m, mean total cost = 2875.327
#   height = 9.00 m, mean total cost = 3196.546
#   height = 9.50 m, mean total cost = 3536.228
#   height = 10.00 m, mean total cost = 3891.653
#   height = 10.50 m, mean total cost = 4272.812
#   height = 11.00 m, mean total cost = 4691.628
#   height = 11.50 m, mean total cost = 5137.550
#   height = 12.00 m, mean total cost = 5601.687
# Round 5000000: best height 3.00 m, mean cost 679.425, r=541.154, separated=False
# Selected design height: 3.00 m

# %%
x=60*4+9
print(10*60*(5000000/x))
12000000/12048192.771084337
# Out:
# 12048192.771084337
# 0.9960000000000001

# %%
import math
import numpy as np
delta=0.05
# --- Helper: required samples for a given assumed gap ---
def required_samples_for_gap(
    gap: float,
    D_max_total: float,
    num_cands: int,
    delta: float,
    S_max: int = 10**16,
) -> int:
    """
    Solve for S such that 2 * r(S) <= gap, where
    r(S) = D_max_total * sqrt( log(2 * K * S * (S + 1) / delta) / (2 S) ).
    """
    target = gap   # need r(S) <= gap/2

    def radius(S: int) -> float:
        log_term = math.log(
            (2.0 * num_cands * S * (S + 1)) / max(delta, 1e-16)
        )
        return D_max_total * math.sqrt(log_term / (2.0 * S))

    # If S=1 already enough (unlikely), return 1
    if radius(1) <= target:
        return 1

    # Exponential search to bracket S
    low, high = 1, 1
    while high < S_max and radius(high) > target:
        low = high
        high *= 2

    if high >= S_max and radius(high) > target:
        # Could not find S within S_max
        return S_max

    # Binary search between low and high
    while low + 1 < high:
        mid = (low + high) // 2
        if radius(mid) <= target:
            high = mid
        else:
            low = mid

    return high


# --- Compute D_max_total and num_cands from your existing objects ---

# damage_costs: full damage curve (million EUR)
# years_range: (start_year, end_year)
# candidate_indices: indices of surviving heights
# delta: your bandit delta

start_year, end_year = years_range
n_years = end_year - start_year + 1
d_max = float(np.max(damage_costs))
D_max_total = n_years * d_max
num_cands = len(candidate_indices)

# --- Assume the gap between best & second best is about 30 ---
gap_assumed = 30.0

S_req = required_samples_for_gap(
    gap=(714-679),
    D_max_total=D_max_total,
    num_cands=num_cands,
    delta=delta,
)

print(f"Assumed gap = {gap_assumed:.1f}")
print(f"Approx. total samples needed for separation: {S_req}")
print(f"Approx. samples per candidate: {S_req / 506024096:.1f}")
# Out:
# Assumed gap = 30.0
# Approx. total samples needed for separation: 1558866198
# Approx. samples per candidate: 3.1

# %%
((9095155553/10000000)*(9*60))/(3600*24)
# Out:
# 5.684472220625
