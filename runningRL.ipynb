# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates,
)

damage_file = "Damage_cost_curves.tab"
protection_file = "Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# --- 1) Load cost curves ---
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# --- 2) Prune candidates ---
start_year, end_year = years_range
n_years = end_year - start_year + 1

candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)

print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# --- 3) Load predictive posterior + future MSL paths from NPZ ---
pp = np.load("pp_inputs_halmsdad_pp_mixture_2025_2100.npz")

# Posterior draws (flattened)
eta0_s   = pp["eta0"].reshape(-1)
eta1_s   = pp["eta1"].reshape(-1)
alpha0_s = pp["alpha0"].reshape(-1)
xi_s     = pp["xi"].reshape(-1)
u_cm     = float(pp["u"])  # threshold in cm, if you want to store/pass it

posterior_params = {
    "eta0": eta0_s,
    "eta1": eta1_s,
    "alpha0": alpha0_s,
    "xi": xi_s,
    # Optional: if you want run_bandit_from_candidates to pick it up:
    "u": u_cm,
}

# Future MSL information (already in cm)
years_future   = pp["years_future"]      # shape (T_future,)
X_future_paths = pp["X_future_paths"]    # shape (M_pred, T_future), in cm

# --- 4) Run the bandit on the pruned candidate set ---
rng = np.random.default_rng(42)

best_height, history = run_bandit_from_candidates(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=100000,
    rng=rng,
    verbose=True,
)

best_height
# Out:
# Round 1000: best height 2.00 m, mean cost 269.673, r=28349.362, separated=False
# Round 2000: best height 2.00 m, mean cost 271.483, r=20705.403, separated=False
# Round 3000: best height 2.00 m, mean cost 267.833, r=17213.065, separated=False
# Round 4000: best height 2.00 m, mean cost 266.639, r=15092.864, separated=False
# Round 5000: best height 2.00 m, mean cost 267.499, r=13627.056, separated=False
# Round 6000: best height 2.00 m, mean cost 269.154, r=12534.105, separated=False
# Round 7000: best height 2.00 m, mean cost 267.402, r=11677.682, separated=False
# Round 8000: best height 2.00 m, mean cost 266.897, r=10982.564, separated=False
# Round 9000: best height 2.00 m, mean cost 266.412, r=10403.357, separated=False
# Round 10000: best height 2.00 m, mean cost 264.953, r=9910.801, separated=False
# Round 11000: best height 2.00 m, mean cost 264.059, r=9485.068, separated=False
# Round 12000: best height 2.00 m, mean cost 264.339, r=9112.171, separated=False
# Round 13000: best height 2.00 m, mean cost 263.387, r=8781.921, separated=False
# Round 14000: best height 2.00 m, mean cost 263.633, r=8486.693, separated=False
# Round 15000: best height 2.00 m, mean cost 262.186, r=8220.650, separated=False
# Round 16000: best height 2.00 m, mean cost 265.140, r=7979.238, separated=False
# Round 17000: best height 2.00 m, mean cost 266.384, r=7758.842, separated=False
# Round 18000: best height 2.00 m, mean cost 266.832, r=7556.553, separated=False
# Round 19000: best height 2.00 m, mean cost 267.962, r=7369.996, separated=False
# Round 20000: best height 2.00 m, mean cost 266.868, r=7197.216, separated=False
# Round 21000: best height 2.00 m, mean cost 269.989, r=7036.579, separated=False
# Round 22000: best height 2.00 m, mean cost 271.892, r=6886.714, separated=False
# Round 23000: best height 2.00 m, mean cost 271.563, r=6746.458, separated=False
# Round 24000: best height 2.00 m, mean cost 270.719, r=6614.816, separated=False
# Round 25000: best height 2.00 m, mean cost 270.700, r=6490.932, separated=False
# Round 26000: best height 2.00 m, mean cost 270.974, r=6374.067, separated=False
# Round 27000: best height 2.00 m, mean cost 272.290, r=6263.575, separated=False
# Round 28000: best height 2.00 m, mean cost 272.054, r=6158.892, separated=False
# Round 29000: best height 2.00 m, mean cost 272.377, r=6059.521, separated=False
# Round 30000: best height 2.00 m, mean cost 271.851, r=5965.024, separated=False
# Round 31000: best height 2.00 m, mean cost 271.401, r=5875.012, separated=False
# Round 32000: best height 2.00 m, mean cost 270.838, r=5789.136, separated=False
# Round 33000: best height 2.00 m, mean cost 270.725, r=5707.087, separated=False
# Round 34000: best height 2.00 m, mean cost 270.495, r=5628.585, separated=False
# Round 35000: best height 2.00 m, mean cost 271.440, r=5553.381, separated=False
# Round 36000: best height 2.00 m, mean cost 270.854, r=5481.246, separated=False
# Round 37000: best height 2.00 m, mean cost 270.403, r=5411.977, separated=False
# Round 38000: best height 2.00 m, mean cost 269.856, r=5345.385, separated=False
# Round 39000: best height 2.00 m, mean cost 269.938, r=5281.303, separated=False
# Round 40000: best height 2.00 m, mean cost 270.081, r=5219.573, separated=False
# Round 41000: best height 2.00 m, mean cost 270.006, r=5160.055, separated=False
# Round 42000: best height 2.00 m, mean cost 270.013, r=5102.618, separated=False
# Round 43000: best height 2.00 m, mean cost 270.191, r=5047.143, separated=False
# Round 44000: best height 2.00 m, mean cost 270.976, r=4993.518, separated=False
# Round 45000: best height 2.00 m, mean cost 270.709, r=4941.644, separated=False
# Round 46000: best height 2.00 m, mean cost 270.564, r=4891.425, separated=False
# Round 47000: best height 2.00 m, mean cost 270.298, r=4842.774, separated=False
# Round 48000: best height 2.00 m, mean cost 270.973, r=4795.611, separated=False
# Round 49000: best height 2.00 m, mean cost 270.959, r=4749.861, separated=False
# Round 50000: best height 2.00 m, mean cost 270.648, r=4705.453, separated=False
# Round 51000: best height 2.00 m, mean cost 271.234, r=4662.324, separated=False
# Round 52000: best height 2.00 m, mean cost 271.060, r=4620.412, separated=False
# Round 53000: best height 2.00 m, mean cost 270.739, r=4579.659, separated=False
# Round 54000: best height 2.00 m, mean cost 271.991, r=4540.015, separated=False
# Round 55000: best height 2.00 m, mean cost 272.262, r=4501.428, separated=False
# Round 56000: best height 2.00 m, mean cost 272.053, r=4463.851, separated=False
# Round 57000: best height 2.00 m, mean cost 272.397, r=4427.242, separated=False
# Round 58000: best height 2.00 m, mean cost 272.493, r=4391.559, separated=False
# Round 59000: best height 2.00 m, mean cost 272.503, r=4356.763, separated=False
# Round 60000: best height 2.00 m, mean cost 272.781, r=4322.818, separated=False
# Round 61000: best height 2.00 m, mean cost 272.445, r=4289.689, separated=False
# Round 62000: best height 2.00 m, mean cost 272.279, r=4257.344, separated=False
# Round 63000: best height 2.00 m, mean cost 272.221, r=4225.751, separated=False
# Round 64000: best height 2.00 m, mean cost 272.015, r=4194.883, separated=False
# Round 65000: best height 2.00 m, mean cost 272.398, r=4164.711, separated=False
# Round 66000: best height 2.00 m, mean cost 272.316, r=4135.210, separated=False
# Round 67000: best height 2.00 m, mean cost 273.856, r=4106.354, separated=False
# Round 68000: best height 2.00 m, mean cost 274.272, r=4078.121, separated=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      24 # --- 4) Run the bandit on the pruned candidate set ---
#      25 rng = np.random.default_rng(42)
# ---> 27 best_height, history = run_bandit_from_candidates(
#      28     heights=heights,
#      29     damage_costs=damage_costs,
#      30     protection_costs=protection_costs,
#      31     candidate_indices=candidate_indices,
#      32     years_all=years_future,
#      33     X_pred_paths_cm=X_future_paths,
#      34     posterior_params=posterior_params,
#      35     years_range=years_range,
#      36     delta=0.05,
#      37     max_rounds=100000,
#      38     rng=rng,
#      39     verbose=True,
#      40 )
#      42 best_height
#
# File c:\Users\johan\OneDrive\Skrivbord\Python_vscode\flood_bandit\optimal_levee_bandit.py:819, in run_bandit_from_candidates(heights, damage_costs, protection_costs, candidate_indices, years_all, X_pred_paths_cm, posterior_params, years_range, delta, max_rounds, rng, verbose)
#     816 X_t_series_cm = X_paths_slice_cm[m]  # shape (n_years,)
#     818 # Simulate annual maxima in cm, then convert to metres
# --> 819 maxima_cm = simulate_annual_max_pp(
#     820     eta0=eta0,
#     821     eta1=eta1,
#     822     alpha0=alpha0,
#     823     xi=xi,
#     824     X_t_series_cm=X_t_series_cm,
#     825     u_cm=u_cm,
#     826     rng=rng,
#     827 )
#     828 maxima_m = maxima_cm / 100.0  # cm → m, shape (n_years,)
#     830 # --- Accumulate damage for all candidates (vectorised) ---
#     831 # exceedances: shape (C, n_years)
#
# File c:\Users\johan\OneDrive\Skrivbord\Python_vscode\flood_bandit\optimal_levee_bandit.py:461, in simulate_annual_max_pp(eta0, eta1, alpha0, xi, X_t_series_cm, u_cm, rng)
#     458         else:
#     459             # Inverse CDF for GPD: z = σ/ξ * ((1 - U)^(-ξ) - 1)
#     460             Z = sigma / xi * ((1.0 - U) ** (-xi) - 1.0)
# --> 461         maxima_cm[j] = u_cm + Z.max()
#     463 return maxima_cm
#
# File c:\Users\johan\miniconda3\envs\flood_pymc\Lib\site-packages\numpy\_core\_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      35     _complex_to_float.update({
#      36         nt.dtype(nt.clongdouble): nt.dtype(nt.longdouble),
#      37     })
#      39 # avoid keyword arguments to speed up parsing, saves about 15%-20% for very
#      40 # small reductions
# ---> 41 def _amax(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
#      43     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      45 def _amin(a, axis=None, out=None, keepdims=False,
#      46           initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
import numpy as np
from optimal_levee_bandit import (
    load_cost_curves,
    prune_candidates,
    run_bandit_from_candidates_eff,  # our new efficient function
)

damage_file = "Damage_cost_curves.tab"
protection_file = "Protection_cost_curves_high_estimate.tab"
city = "Halmstad"
years_range = (2025, 2100)

# 1. Load cost curves
heights, damage_costs, protection_costs = load_cost_curves(
    damage_file, protection_file, city
)

# 2. Prune deterministically dominated heights
start_year, end_year = years_range
n_years = end_year - start_year + 1
candidate_indices = prune_candidates(
    heights=heights,
    protection_costs=protection_costs,
    damage_costs=damage_costs,
    n_years=n_years,
)
print(f"Pruned from {len(heights)} to {len(candidate_indices)} candidate heights.")
print("Candidate heights (m):", heights[candidate_indices])
# Out:
# Pruned from 25 to 25 candidate heights.
# Candidate heights (m): [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12. ]

# %%
# 3. Load predictive posterior and future MSL paths from your NPZ
pp = np.load("pp_inputs_halmsdad_pp_mixture_2025_2100.npz")
posterior_params = {
    "eta0": pp["eta0"],
    "eta1": pp["eta1"],
    "alpha0": pp["alpha0"],
    "xi": pp["xi"],
    "u": float(pp["u"]),  # optional threshold (cm)
}
years_future   = pp["years_future"]
X_future_paths = pp["X_future_paths"]  # already in cm

# 4. Run the efficient bandit
rng = np.random.default_rng(42)
best_height, history = run_bandit_from_candidates_eff(
    heights=heights,
    damage_costs=damage_costs,
    protection_costs=protection_costs,
    candidate_indices=candidate_indices,
    years_all=years_future,
    X_pred_paths_cm=X_future_paths,
    posterior_params=posterior_params,
    years_range=years_range,
    delta=0.05,
    max_rounds=10000000,
    rng=rng,
    verbose=True,
)

print(f"Selected design height: {best_height:.2f} m")
# Out:
# Round 100000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2041.578
#   height = 0.50 m, mean total cost = 2060.106
#   height = 1.00 m, mean total cost = 2028.238
#   height = 1.50 m, mean total cost = 1458.832
#   height = 2.00 m, mean total cost = 922.871
#   height = 2.50 m, mean total cost = 710.956
#   height = 3.00 m, mean total cost = 674.724
#   height = 3.50 m, mean total cost = 717.642
#   height = 4.00 m, mean total cost = 814.181
#   height = 4.50 m, mean total cost = 944.380
#   height = 5.00 m, mean total cost = 1100.913
#   height = 5.50 m, mean total cost = 1288.429
#   height = 6.00 m, mean total cost = 1499.487
#   height = 6.50 m, mean total cost = 1744.152
#   height = 7.00 m, mean total cost = 2003.489
#   height = 7.50 m, mean total cost = 2276.783
#   height = 8.00 m, mean total cost = 2563.104
#   height = 8.50 m, mean total cost = 2874.243
#   height = 9.00 m, mean total cost = 3195.570
#   height = 9.50 m, mean total cost = 3535.763
#   height = 10.00 m, mean total cost = 3890.894
#   height = 10.50 m, mean total cost = 4272.433
#   height = 11.00 m, mean total cost = 4690.948
#   height = 11.50 m, mean total cost = 5137.126
#   height = 12.00 m, mean total cost = 5601.068
# Round 100000: best height 3.00 m, mean cost 674.724, r=3407.088, separated=False
#
# Round 200000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2050.194
#   height = 0.50 m, mean total cost = 2068.722
#   height = 1.00 m, mean total cost = 2036.932
#   height = 1.50 m, mean total cost = 1467.859
#   height = 2.00 m, mean total cost = 931.854
#   height = 2.50 m, mean total cost = 719.674
#   height = 3.00 m, mean total cost = 682.989
#   height = 3.50 m, mean total cost = 724.841
#   height = 4.00 m, mean total cost = 820.968
#   height = 4.50 m, mean total cost = 950.147
#   height = 5.00 m, mean total cost = 1105.978
#   height = 5.50 m, mean total cost = 1292.879
#   height = 6.00 m, mean total cost = 1503.126
#   height = 6.50 m, mean total cost = 1747.348
#   height = 7.00 m, mean total cost = 2006.416
#   height = 7.50 m, mean total cost = 2279.299
#   height = 8.00 m, mean total cost = 2564.988
#   height = 8.50 m, mean total cost = 2876.029
#   height = 9.00 m, mean total cost = 3197.093
#   height = 9.50 m, mean total cost = 3536.803
#   height = 10.00 m, mean total cost = 3892.283
#   height = 10.50 m, mean total cost = 4273.368
#   height = 11.00 m, mean total cost = 4691.670
#   height = 11.50 m, mean total cost = 5137.493
#   height = 12.00 m, mean total cost = 5601.196
# Round 200000: best height 3.00 m, mean cost 682.989, r=2464.330, separated=False
#
# Round 300000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2048.576
#   height = 0.50 m, mean total cost = 2067.104
#   height = 1.00 m, mean total cost = 2035.191
#   height = 1.50 m, mean total cost = 1465.730
#   height = 2.00 m, mean total cost = 930.449
#   height = 2.50 m, mean total cost = 718.915
#   height = 3.00 m, mean total cost = 682.577
#   height = 3.50 m, mean total cost = 724.676
#   height = 4.00 m, mean total cost = 820.884
#   height = 4.50 m, mean total cost = 950.203
#   height = 5.00 m, mean total cost = 1106.205
#   height = 5.50 m, mean total cost = 1292.887
#   height = 6.00 m, mean total cost = 1503.263
#   height = 6.50 m, mean total cost = 1747.611
#   height = 7.00 m, mean total cost = 2006.715
#   height = 7.50 m, mean total cost = 2279.662
#   height = 8.00 m, mean total cost = 2565.409
#   height = 8.50 m, mean total cost = 2876.444
#   height = 9.00 m, mean total cost = 3197.558
#   height = 9.50 m, mean total cost = 3537.249
#   height = 10.00 m, mean total cost = 3892.568
#   height = 10.50 m, mean total cost = 4273.595
#   height = 11.00 m, mean total cost = 4692.102
#   height = 11.50 m, mean total cost = 5137.978
#   height = 12.00 m, mean total cost = 5601.862
# Round 300000: best height 3.00 m, mean cost 682.577, r=2038.000, separated=False
#
# Round 400000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2046.017
#   height = 0.50 m, mean total cost = 2064.545
#   height = 1.00 m, mean total cost = 2032.663
#   height = 1.50 m, mean total cost = 1463.114
#   height = 2.00 m, mean total cost = 927.492
#   height = 2.50 m, mean total cost = 716.256
#   height = 3.00 m, mean total cost = 680.182
#   height = 3.50 m, mean total cost = 722.361
#   height = 4.00 m, mean total cost = 818.515
#   height = 4.50 m, mean total cost = 948.035
#   height = 5.00 m, mean total cost = 1104.091
#   height = 5.50 m, mean total cost = 1290.781
#   height = 6.00 m, mean total cost = 1501.358
#   height = 6.50 m, mean total cost = 1745.863
#   height = 7.00 m, mean total cost = 2004.968
#   height = 7.50 m, mean total cost = 2277.987
#   height = 8.00 m, mean total cost = 2563.844
#   height = 8.50 m, mean total cost = 2874.926
#   height = 9.00 m, mean total cost = 3196.131
#   height = 9.50 m, mean total cost = 3535.941
#   height = 10.00 m, mean total cost = 3891.391
#   height = 10.50 m, mean total cost = 4272.567
#   height = 11.00 m, mean total cost = 4691.214
#   height = 11.50 m, mean total cost = 5137.184
#   height = 12.00 m, mean total cost = 5601.270
# Round 400000: best height 3.00 m, mean cost 680.182, r=1780.692, separated=False
#
# Round 500000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2045.889
#   height = 0.50 m, mean total cost = 2064.417
#   height = 1.00 m, mean total cost = 2032.450
#   height = 1.50 m, mean total cost = 1462.774
#   height = 2.00 m, mean total cost = 927.508
#   height = 2.50 m, mean total cost = 716.481
#   height = 3.00 m, mean total cost = 680.503
#   height = 3.50 m, mean total cost = 722.802
#   height = 4.00 m, mean total cost = 819.057
#   height = 4.50 m, mean total cost = 948.666
#   height = 5.00 m, mean total cost = 1104.783
#   height = 5.50 m, mean total cost = 1291.499
#   height = 6.00 m, mean total cost = 1502.194
#   height = 6.50 m, mean total cost = 1746.664
#   height = 7.00 m, mean total cost = 2005.760
#   height = 7.50 m, mean total cost = 2278.733
#   height = 8.00 m, mean total cost = 2564.642
#   height = 8.50 m, mean total cost = 2875.807
#   height = 9.00 m, mean total cost = 3197.018
#   height = 9.50 m, mean total cost = 3536.735
#   height = 10.00 m, mean total cost = 3892.112
#   height = 10.50 m, mean total cost = 4273.269
#   height = 11.00 m, mean total cost = 4691.906
#   height = 11.50 m, mean total cost = 5137.826
#   height = 12.00 m, mean total cost = 5601.757
# Round 500000: best height 3.00 m, mean cost 680.503, r=1603.529, separated=False
#
# Round 600000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2045.448
#   height = 0.50 m, mean total cost = 2063.976
#   height = 1.00 m, mean total cost = 2031.957
#   height = 1.50 m, mean total cost = 1462.266
#   height = 2.00 m, mean total cost = 927.142
#   height = 2.50 m, mean total cost = 716.228
#   height = 3.00 m, mean total cost = 680.271
#   height = 3.50 m, mean total cost = 722.544
#   height = 4.00 m, mean total cost = 818.763
#   height = 4.50 m, mean total cost = 948.377
#   height = 5.00 m, mean total cost = 1104.499
#   height = 5.50 m, mean total cost = 1291.170
#   height = 6.00 m, mean total cost = 1501.848
#   height = 6.50 m, mean total cost = 1746.267
#   height = 7.00 m, mean total cost = 2005.384
#   height = 7.50 m, mean total cost = 2278.367
#   height = 8.00 m, mean total cost = 2564.362
#   height = 8.50 m, mean total cost = 2875.488
#   height = 9.00 m, mean total cost = 3196.768
#   height = 9.50 m, mean total cost = 3536.421
#   height = 10.00 m, mean total cost = 3891.794
#   height = 10.50 m, mean total cost = 4272.987
#   height = 11.00 m, mean total cost = 4691.643
#   height = 11.50 m, mean total cost = 5137.572
#   height = 12.00 m, mean total cost = 5601.459
# Round 600000: best height 3.00 m, mean cost 680.271, r=1471.843, separated=False
#
# Round 700000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2044.532
#   height = 0.50 m, mean total cost = 2063.060
#   height = 1.00 m, mean total cost = 2031.039
#   height = 1.50 m, mean total cost = 1461.362
#   height = 2.00 m, mean total cost = 926.174
#   height = 2.50 m, mean total cost = 715.306
#   height = 3.00 m, mean total cost = 679.357
#   height = 3.50 m, mean total cost = 721.566
#   height = 4.00 m, mean total cost = 817.766
#   height = 4.50 m, mean total cost = 947.496
#   height = 5.00 m, mean total cost = 1103.672
#   height = 5.50 m, mean total cost = 1290.413
#   height = 6.00 m, mean total cost = 1501.153
#   height = 6.50 m, mean total cost = 1745.676
#   height = 7.00 m, mean total cost = 2004.862
#   height = 7.50 m, mean total cost = 2277.864
#   height = 8.00 m, mean total cost = 2563.887
#   height = 8.50 m, mean total cost = 2875.058
#   height = 9.00 m, mean total cost = 3196.371
#   height = 9.50 m, mean total cost = 3536.021
#   height = 10.00 m, mean total cost = 3891.334
#   height = 10.50 m, mean total cost = 4272.538
#   height = 11.00 m, mean total cost = 4691.215
#   height = 11.50 m, mean total cost = 5137.140
#   height = 12.00 m, mean total cost = 5601.031
# Round 700000: best height 3.00 m, mean cost 679.357, r=1368.915, separated=False
#
# Round 800000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.797
#   height = 0.50 m, mean total cost = 2062.325
#   height = 1.00 m, mean total cost = 2030.284
#   height = 1.50 m, mean total cost = 1460.571
#   height = 2.00 m, mean total cost = 925.448
#   height = 2.50 m, mean total cost = 714.630
#   height = 3.00 m, mean total cost = 678.678
#   height = 3.50 m, mean total cost = 720.973
#   height = 4.00 m, mean total cost = 817.287
#   height = 4.50 m, mean total cost = 947.065
#   height = 5.00 m, mean total cost = 1103.254
#   height = 5.50 m, mean total cost = 1290.104
#   height = 6.00 m, mean total cost = 1500.863
#   height = 6.50 m, mean total cost = 1745.386
#   height = 7.00 m, mean total cost = 2004.607
#   height = 7.50 m, mean total cost = 2277.630
#   height = 8.00 m, mean total cost = 2563.670
#   height = 8.50 m, mean total cost = 2874.856
#   height = 9.00 m, mean total cost = 3196.149
#   height = 9.50 m, mean total cost = 3535.834
#   height = 10.00 m, mean total cost = 3891.180
#   height = 10.50 m, mean total cost = 4272.385
#   height = 11.00 m, mean total cost = 4691.179
#   height = 11.50 m, mean total cost = 5137.071
#   height = 12.00 m, mean total cost = 5601.063
# Round 800000: best height 3.00 m, mean cost 678.678, r=1285.547, separated=False
#
# Round 900000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.356
#   height = 0.50 m, mean total cost = 2061.884
#   height = 1.00 m, mean total cost = 2029.772
#   height = 1.50 m, mean total cost = 1460.152
#   height = 2.00 m, mean total cost = 925.134
#   height = 2.50 m, mean total cost = 714.300
#   height = 3.00 m, mean total cost = 678.409
#   height = 3.50 m, mean total cost = 720.725
#   height = 4.00 m, mean total cost = 817.041
#   height = 4.50 m, mean total cost = 946.873
#   height = 5.00 m, mean total cost = 1103.159
#   height = 5.50 m, mean total cost = 1290.027
#   height = 6.00 m, mean total cost = 1500.758
#   height = 6.50 m, mean total cost = 1745.263
#   height = 7.00 m, mean total cost = 2004.490
#   height = 7.50 m, mean total cost = 2277.563
#   height = 8.00 m, mean total cost = 2563.599
#   height = 8.50 m, mean total cost = 2874.771
#   height = 9.00 m, mean total cost = 3196.049
#   height = 9.50 m, mean total cost = 3535.704
#   height = 10.00 m, mean total cost = 3890.999
#   height = 10.50 m, mean total cost = 4272.253
#   height = 11.00 m, mean total cost = 4691.034
#   height = 11.50 m, mean total cost = 5136.956
#   height = 12.00 m, mean total cost = 5600.978
# Round 900000: best height 3.00 m, mean cost 678.409, r=1216.206, separated=False
#
# Round 1000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.051
#   height = 0.50 m, mean total cost = 2061.579
#   height = 1.00 m, mean total cost = 2029.442
#   height = 1.50 m, mean total cost = 1459.863
#   height = 2.00 m, mean total cost = 924.794
#   height = 2.50 m, mean total cost = 714.062
#   height = 3.00 m, mean total cost = 678.186
#   height = 3.50 m, mean total cost = 720.578
#   height = 4.00 m, mean total cost = 816.943
#   height = 4.50 m, mean total cost = 946.796
#   height = 5.00 m, mean total cost = 1103.022
#   height = 5.50 m, mean total cost = 1289.867
#   height = 6.00 m, mean total cost = 1500.596
#   height = 6.50 m, mean total cost = 1745.080
#   height = 7.00 m, mean total cost = 2004.345
#   height = 7.50 m, mean total cost = 2277.453
#   height = 8.00 m, mean total cost = 2563.512
#   height = 8.50 m, mean total cost = 2874.662
#   height = 9.00 m, mean total cost = 3195.956
#   height = 9.50 m, mean total cost = 3535.646
#   height = 10.00 m, mean total cost = 3890.951
#   height = 10.50 m, mean total cost = 4272.191
#   height = 11.00 m, mean total cost = 4690.981
#   height = 11.50 m, mean total cost = 5136.884
#   height = 12.00 m, mean total cost = 5600.881
# Round 1000000: best height 3.00 m, mean cost 678.186, r=1157.330, separated=False
#
# Round 1100000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.678
#   height = 0.50 m, mean total cost = 2062.206
#   height = 1.00 m, mean total cost = 2030.075
#   height = 1.50 m, mean total cost = 1460.578
#   height = 2.00 m, mean total cost = 925.468
#   height = 2.50 m, mean total cost = 714.596
#   height = 3.00 m, mean total cost = 678.616
#   height = 3.50 m, mean total cost = 720.909
#   height = 4.00 m, mean total cost = 817.200
#   height = 4.50 m, mean total cost = 947.060
#   height = 5.00 m, mean total cost = 1103.257
#   height = 5.50 m, mean total cost = 1290.127
#   height = 6.00 m, mean total cost = 1500.806
#   height = 6.50 m, mean total cost = 1745.261
#   height = 7.00 m, mean total cost = 2004.518
#   height = 7.50 m, mean total cost = 2277.618
#   height = 8.00 m, mean total cost = 2563.704
#   height = 8.50 m, mean total cost = 2874.831
#   height = 9.00 m, mean total cost = 3196.082
#   height = 9.50 m, mean total cost = 3535.777
#   height = 10.00 m, mean total cost = 3891.134
#   height = 10.50 m, mean total cost = 4272.367
#   height = 11.00 m, mean total cost = 4691.097
#   height = 11.50 m, mean total cost = 5136.913
#   height = 12.00 m, mean total cost = 5600.921
# Round 1100000: best height 3.00 m, mean cost 678.616, r=1106.512, separated=False
#
# Round 1200000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.231
#   height = 0.50 m, mean total cost = 2061.759
#   height = 1.00 m, mean total cost = 2029.642
#   height = 1.50 m, mean total cost = 1460.083
#   height = 2.00 m, mean total cost = 924.982
#   height = 2.50 m, mean total cost = 714.147
#   height = 3.00 m, mean total cost = 678.182
#   height = 3.50 m, mean total cost = 720.512
#   height = 4.00 m, mean total cost = 816.862
#   height = 4.50 m, mean total cost = 946.807
#   height = 5.00 m, mean total cost = 1103.036
#   height = 5.50 m, mean total cost = 1289.901
#   height = 6.00 m, mean total cost = 1500.598
#   height = 6.50 m, mean total cost = 1745.119
#   height = 7.00 m, mean total cost = 2004.360
#   height = 7.50 m, mean total cost = 2277.433
#   height = 8.00 m, mean total cost = 2563.557
#   height = 8.50 m, mean total cost = 2874.761
#   height = 9.00 m, mean total cost = 3195.993
#   height = 9.50 m, mean total cost = 3535.648
#   height = 10.00 m, mean total cost = 3890.993
#   height = 10.50 m, mean total cost = 4272.200
#   height = 11.00 m, mean total cost = 4690.912
#   height = 11.50 m, mean total cost = 5136.723
#   height = 12.00 m, mean total cost = 5600.760
# Round 1200000: best height 3.00 m, mean cost 678.182, r=1062.055, separated=False
#
# Round 1300000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.758
#   height = 0.50 m, mean total cost = 2061.286
#   height = 1.00 m, mean total cost = 2029.154
#   height = 1.50 m, mean total cost = 1459.557
#   height = 2.00 m, mean total cost = 924.539
#   height = 2.50 m, mean total cost = 713.761
#   height = 3.00 m, mean total cost = 677.814
#   height = 3.50 m, mean total cost = 720.160
#   height = 4.00 m, mean total cost = 816.540
#   height = 4.50 m, mean total cost = 946.493
#   height = 5.00 m, mean total cost = 1102.719
#   height = 5.50 m, mean total cost = 1289.615
#   height = 6.00 m, mean total cost = 1500.301
#   height = 6.50 m, mean total cost = 1744.863
#   height = 7.00 m, mean total cost = 2004.136
#   height = 7.50 m, mean total cost = 2277.231
#   height = 8.00 m, mean total cost = 2563.368
#   height = 8.50 m, mean total cost = 2874.599
#   height = 9.00 m, mean total cost = 3195.789
#   height = 9.50 m, mean total cost = 3535.469
#   height = 10.00 m, mean total cost = 3890.844
#   height = 10.50 m, mean total cost = 4272.016
#   height = 11.00 m, mean total cost = 4690.733
#   height = 11.50 m, mean total cost = 5136.569
#   height = 12.00 m, mean total cost = 5600.648
# Round 1300000: best height 3.00 m, mean cost 677.814, r=1022.727, separated=False
#
# Round 1400000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.667
#   height = 0.50 m, mean total cost = 2061.195
#   height = 1.00 m, mean total cost = 2029.070
#   height = 1.50 m, mean total cost = 1459.475
#   height = 2.00 m, mean total cost = 924.380
#   height = 2.50 m, mean total cost = 713.627
#   height = 3.00 m, mean total cost = 677.713
#   height = 3.50 m, mean total cost = 720.130
#   height = 4.00 m, mean total cost = 816.611
#   height = 4.50 m, mean total cost = 946.568
#   height = 5.00 m, mean total cost = 1102.838
#   height = 5.50 m, mean total cost = 1289.755
#   height = 6.00 m, mean total cost = 1500.432
#   height = 6.50 m, mean total cost = 1744.997
#   height = 7.00 m, mean total cost = 2004.286
#   height = 7.50 m, mean total cost = 2277.368
#   height = 8.00 m, mean total cost = 2563.530
#   height = 8.50 m, mean total cost = 2874.772
#   height = 9.00 m, mean total cost = 3195.939
#   height = 9.50 m, mean total cost = 3535.664
#   height = 10.00 m, mean total cost = 3890.994
#   height = 10.50 m, mean total cost = 4272.157
#   height = 11.00 m, mean total cost = 4690.880
#   height = 11.50 m, mean total cost = 5136.711
#   height = 12.00 m, mean total cost = 5600.785
# Round 1400000: best height 3.00 m, mean cost 677.713, r=987.605, separated=False
#
# Round 1500000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.077
#   height = 0.50 m, mean total cost = 2061.605
#   height = 1.00 m, mean total cost = 2029.493
#   height = 1.50 m, mean total cost = 1459.882
#   height = 2.00 m, mean total cost = 924.746
#   height = 2.50 m, mean total cost = 713.995
#   height = 3.00 m, mean total cost = 678.087
#   height = 3.50 m, mean total cost = 720.535
#   height = 4.00 m, mean total cost = 816.991
#   height = 4.50 m, mean total cost = 946.923
#   height = 5.00 m, mean total cost = 1103.216
#   height = 5.50 m, mean total cost = 1290.141
#   height = 6.00 m, mean total cost = 1500.767
#   height = 6.50 m, mean total cost = 1745.308
#   height = 7.00 m, mean total cost = 2004.576
#   height = 7.50 m, mean total cost = 2277.673
#   height = 8.00 m, mean total cost = 2563.830
#   height = 8.50 m, mean total cost = 2875.058
#   height = 9.00 m, mean total cost = 3196.261
#   height = 9.50 m, mean total cost = 3535.995
#   height = 10.00 m, mean total cost = 3891.299
#   height = 10.50 m, mean total cost = 4272.441
#   height = 11.00 m, mean total cost = 4691.195
#   height = 11.50 m, mean total cost = 5137.039
#   height = 12.00 m, mean total cost = 5601.136
# Round 1500000: best height 3.00 m, mean cost 678.087, r=955.985, separated=False
#
# Round 1600000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.788
#   height = 0.50 m, mean total cost = 2061.316
#   height = 1.00 m, mean total cost = 2029.203
#   height = 1.50 m, mean total cost = 1459.591
#   height = 2.00 m, mean total cost = 924.449
#   height = 2.50 m, mean total cost = 713.695
#   height = 3.00 m, mean total cost = 677.781
#   height = 3.50 m, mean total cost = 720.230
#   height = 4.00 m, mean total cost = 816.741
#   height = 4.50 m, mean total cost = 946.715
#   height = 5.00 m, mean total cost = 1103.027
#   height = 5.50 m, mean total cost = 1289.957
#   height = 6.00 m, mean total cost = 1500.585
#   height = 6.50 m, mean total cost = 1745.139
#   height = 7.00 m, mean total cost = 2004.467
#   height = 7.50 m, mean total cost = 2277.571
#   height = 8.00 m, mean total cost = 2563.729
#   height = 8.50 m, mean total cost = 2874.985
#   height = 9.00 m, mean total cost = 3196.231
#   height = 9.50 m, mean total cost = 3535.995
#   height = 10.00 m, mean total cost = 3891.291
#   height = 10.50 m, mean total cost = 4272.431
#   height = 11.00 m, mean total cost = 4691.171
#   height = 11.50 m, mean total cost = 5136.994
#   height = 12.00 m, mean total cost = 5601.098
# Round 1600000: best height 3.00 m, mean cost 677.781, r=927.317, separated=False
#
# Round 1700000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.874
#   height = 0.50 m, mean total cost = 2061.402
#   height = 1.00 m, mean total cost = 2029.293
#   height = 1.50 m, mean total cost = 1459.680
#   height = 2.00 m, mean total cost = 924.524
#   height = 2.50 m, mean total cost = 713.780
#   height = 3.00 m, mean total cost = 677.869
#   height = 3.50 m, mean total cost = 720.297
#   height = 4.00 m, mean total cost = 816.812
#   height = 4.50 m, mean total cost = 946.777
#   height = 5.00 m, mean total cost = 1103.053
#   height = 5.50 m, mean total cost = 1289.928
#   height = 6.00 m, mean total cost = 1500.542
#   height = 6.50 m, mean total cost = 1745.090
#   height = 7.00 m, mean total cost = 2004.432
#   height = 7.50 m, mean total cost = 2277.534
#   height = 8.00 m, mean total cost = 2563.731
#   height = 8.50 m, mean total cost = 2874.961
#   height = 9.00 m, mean total cost = 3196.196
#   height = 9.50 m, mean total cost = 3535.951
#   height = 10.00 m, mean total cost = 3891.242
#   height = 10.50 m, mean total cost = 4272.399
#   height = 11.00 m, mean total cost = 4691.133
#   height = 11.50 m, mean total cost = 5136.957
#   height = 12.00 m, mean total cost = 5601.055
# Round 1700000: best height 3.00 m, mean cost 677.869, r=901.165, separated=False
#
# Round 1800000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.484
#   height = 0.50 m, mean total cost = 2062.012
#   height = 1.00 m, mean total cost = 2029.901
#   height = 1.50 m, mean total cost = 1460.311
#   height = 2.00 m, mean total cost = 925.172
#   height = 2.50 m, mean total cost = 714.416
#   height = 3.00 m, mean total cost = 678.502
#   height = 3.50 m, mean total cost = 720.881
#   height = 4.00 m, mean total cost = 817.343
#   height = 4.50 m, mean total cost = 947.269
#   height = 5.00 m, mean total cost = 1103.476
#   height = 5.50 m, mean total cost = 1290.290
#   height = 6.00 m, mean total cost = 1500.907
#   height = 6.50 m, mean total cost = 1745.444
#   height = 7.00 m, mean total cost = 2004.772
#   height = 7.50 m, mean total cost = 2277.872
#   height = 8.00 m, mean total cost = 2564.052
#   height = 8.50 m, mean total cost = 2875.260
#   height = 9.00 m, mean total cost = 3196.477
#   height = 9.50 m, mean total cost = 3536.220
#   height = 10.00 m, mean total cost = 3891.506
#   height = 10.50 m, mean total cost = 4272.662
#   height = 11.00 m, mean total cost = 4691.367
#   height = 11.50 m, mean total cost = 5137.207
#   height = 12.00 m, mean total cost = 5601.282
# Round 1800000: best height 3.00 m, mean cost 678.502, r=877.180, separated=False
#
# Round 1900000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.167
#   height = 0.50 m, mean total cost = 2061.695
#   height = 1.00 m, mean total cost = 2029.570
#   height = 1.50 m, mean total cost = 1459.978
#   height = 2.00 m, mean total cost = 924.866
#   height = 2.50 m, mean total cost = 714.168
#   height = 3.00 m, mean total cost = 678.242
#   height = 3.50 m, mean total cost = 720.628
#   height = 4.00 m, mean total cost = 817.105
#   height = 4.50 m, mean total cost = 947.030
#   height = 5.00 m, mean total cost = 1103.268
#   height = 5.50 m, mean total cost = 1290.076
#   height = 6.00 m, mean total cost = 1500.710
#   height = 6.50 m, mean total cost = 1745.274
#   height = 7.00 m, mean total cost = 2004.644
#   height = 7.50 m, mean total cost = 2277.729
#   height = 8.00 m, mean total cost = 2563.892
#   height = 8.50 m, mean total cost = 2875.130
#   height = 9.00 m, mean total cost = 3196.361
#   height = 9.50 m, mean total cost = 3536.132
#   height = 10.00 m, mean total cost = 3891.415
#   height = 10.50 m, mean total cost = 4272.591
#   height = 11.00 m, mean total cost = 4691.300
#   height = 11.50 m, mean total cost = 5137.158
#   height = 12.00 m, mean total cost = 5601.249
# Round 1900000: best height 3.00 m, mean cost 678.242, r=855.076, separated=False
#
# Round 2000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.144
#   height = 0.50 m, mean total cost = 2061.672
#   height = 1.00 m, mean total cost = 2029.533
#   height = 1.50 m, mean total cost = 1459.972
#   height = 2.00 m, mean total cost = 924.874
#   height = 2.50 m, mean total cost = 714.185
#   height = 3.00 m, mean total cost = 678.262
#   height = 3.50 m, mean total cost = 720.622
#   height = 4.00 m, mean total cost = 817.100
#   height = 4.50 m, mean total cost = 947.027
#   height = 5.00 m, mean total cost = 1103.243
#   height = 5.50 m, mean total cost = 1290.015
#   height = 6.00 m, mean total cost = 1500.686
#   height = 6.50 m, mean total cost = 1745.262
#   height = 7.00 m, mean total cost = 2004.595
#   height = 7.50 m, mean total cost = 2277.695
#   height = 8.00 m, mean total cost = 2563.853
#   height = 8.50 m, mean total cost = 2875.084
#   height = 9.00 m, mean total cost = 3196.319
#   height = 9.50 m, mean total cost = 3536.085
#   height = 10.00 m, mean total cost = 3891.382
#   height = 10.50 m, mean total cost = 4272.555
#   height = 11.00 m, mean total cost = 4691.255
#   height = 11.50 m, mean total cost = 5137.122
#   height = 12.00 m, mean total cost = 5601.211
# Round 2000000: best height 3.00 m, mean cost 678.262, r=834.618, separated=False
#
# Round 2100000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.929
#   height = 0.50 m, mean total cost = 2061.457
#   height = 1.00 m, mean total cost = 2029.292
#   height = 1.50 m, mean total cost = 1459.744
#   height = 2.00 m, mean total cost = 924.723
#   height = 2.50 m, mean total cost = 714.053
#   height = 3.00 m, mean total cost = 678.152
#   height = 3.50 m, mean total cost = 720.462
#   height = 4.00 m, mean total cost = 816.948
#   height = 4.50 m, mean total cost = 946.891
#   height = 5.00 m, mean total cost = 1103.127
#   height = 5.50 m, mean total cost = 1289.910
#   height = 6.00 m, mean total cost = 1500.586
#   height = 6.50 m, mean total cost = 1745.165
#   height = 7.00 m, mean total cost = 2004.521
#   height = 7.50 m, mean total cost = 2277.613
#   height = 8.00 m, mean total cost = 2563.758
#   height = 8.50 m, mean total cost = 2875.013
#   height = 9.00 m, mean total cost = 3196.267
#   height = 9.50 m, mean total cost = 3536.040
#   height = 10.00 m, mean total cost = 3891.359
#   height = 10.50 m, mean total cost = 4272.571
#   height = 11.00 m, mean total cost = 4691.290
#   height = 11.50 m, mean total cost = 5137.166
#   height = 12.00 m, mean total cost = 5601.269
# Round 2100000: best height 3.00 m, mean cost 678.152, r=815.609, separated=False
#
# Round 2200000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.635
#   height = 0.50 m, mean total cost = 2061.163
#   height = 1.00 m, mean total cost = 2029.010
#   height = 1.50 m, mean total cost = 1459.395
#   height = 2.00 m, mean total cost = 924.361
#   height = 2.50 m, mean total cost = 713.727
#   height = 3.00 m, mean total cost = 677.862
#   height = 3.50 m, mean total cost = 720.186
#   height = 4.00 m, mean total cost = 816.670
#   height = 4.50 m, mean total cost = 946.636
#   height = 5.00 m, mean total cost = 1102.922
#   height = 5.50 m, mean total cost = 1289.722
#   height = 6.00 m, mean total cost = 1500.424
#   height = 6.50 m, mean total cost = 1745.021
#   height = 7.00 m, mean total cost = 2004.386
#   height = 7.50 m, mean total cost = 2277.481
#   height = 8.00 m, mean total cost = 2563.637
#   height = 8.50 m, mean total cost = 2874.880
#   height = 9.00 m, mean total cost = 3196.160
#   height = 9.50 m, mean total cost = 3535.934
#   height = 10.00 m, mean total cost = 3891.260
#   height = 10.50 m, mean total cost = 4272.497
#   height = 11.00 m, mean total cost = 4691.229
#   height = 11.50 m, mean total cost = 5137.126
#   height = 12.00 m, mean total cost = 5601.238
# Round 2200000: best height 3.00 m, mean cost 677.862, r=797.885, separated=False
#
# Round 2300000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.913
#   height = 0.50 m, mean total cost = 2061.441
#   height = 1.00 m, mean total cost = 2029.294
#   height = 1.50 m, mean total cost = 1459.672
#   height = 2.00 m, mean total cost = 924.632
#   height = 2.50 m, mean total cost = 713.995
#   height = 3.00 m, mean total cost = 678.117
#   height = 3.50 m, mean total cost = 720.409
#   height = 4.00 m, mean total cost = 816.861
#   height = 4.50 m, mean total cost = 946.830
#   height = 5.00 m, mean total cost = 1103.106
#   height = 5.50 m, mean total cost = 1289.883
#   height = 6.00 m, mean total cost = 1500.570
#   height = 6.50 m, mean total cost = 1745.138
#   height = 7.00 m, mean total cost = 2004.499
#   height = 7.50 m, mean total cost = 2277.586
#   height = 8.00 m, mean total cost = 2563.750
#   height = 8.50 m, mean total cost = 2874.990
#   height = 9.00 m, mean total cost = 3196.245
#   height = 9.50 m, mean total cost = 3536.020
#   height = 10.00 m, mean total cost = 3891.343
#   height = 10.50 m, mean total cost = 4272.551
#   height = 11.00 m, mean total cost = 4691.293
#   height = 11.50 m, mean total cost = 5137.206
#   height = 12.00 m, mean total cost = 5601.320
# Round 2300000: best height 3.00 m, mean cost 678.117, r=781.307, separated=False
#
# Round 2400000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.705
#   height = 0.50 m, mean total cost = 2061.233
#   height = 1.00 m, mean total cost = 2029.104
#   height = 1.50 m, mean total cost = 1459.479
#   height = 2.00 m, mean total cost = 924.408
#   height = 2.50 m, mean total cost = 713.719
#   height = 3.00 m, mean total cost = 677.776
#   height = 3.50 m, mean total cost = 720.036
#   height = 4.00 m, mean total cost = 816.491
#   height = 4.50 m, mean total cost = 946.459
#   height = 5.00 m, mean total cost = 1102.751
#   height = 5.50 m, mean total cost = 1289.536
#   height = 6.00 m, mean total cost = 1500.231
#   height = 6.50 m, mean total cost = 1744.809
#   height = 7.00 m, mean total cost = 2004.166
#   height = 7.50 m, mean total cost = 2277.266
#   height = 8.00 m, mean total cost = 2563.447
#   height = 8.50 m, mean total cost = 2874.707
#   height = 9.00 m, mean total cost = 3195.985
#   height = 9.50 m, mean total cost = 3535.773
#   height = 10.00 m, mean total cost = 3891.112
#   height = 10.50 m, mean total cost = 4272.346
#   height = 11.00 m, mean total cost = 4691.104
#   height = 11.50 m, mean total cost = 5137.040
#   height = 12.00 m, mean total cost = 5601.163
# Round 2400000: best height 3.00 m, mean cost 677.776, r=765.755, separated=False
#
# Round 2500000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.766
#   height = 0.50 m, mean total cost = 2061.294
#   height = 1.00 m, mean total cost = 2029.163
#   height = 1.50 m, mean total cost = 1459.526
#   height = 2.00 m, mean total cost = 924.490
#   height = 2.50 m, mean total cost = 713.801
#   height = 3.00 m, mean total cost = 677.878
#   height = 3.50 m, mean total cost = 720.150
#   height = 4.00 m, mean total cost = 816.601
#   height = 4.50 m, mean total cost = 946.550
#   height = 5.00 m, mean total cost = 1102.812
#   height = 5.50 m, mean total cost = 1289.599
#   height = 6.00 m, mean total cost = 1500.303
#   height = 6.50 m, mean total cost = 1744.876
#   height = 7.00 m, mean total cost = 2004.257
#   height = 7.50 m, mean total cost = 2277.321
#   height = 8.00 m, mean total cost = 2563.491
#   height = 8.50 m, mean total cost = 2874.729
#   height = 9.00 m, mean total cost = 3196.007
#   height = 9.50 m, mean total cost = 3535.796
#   height = 10.00 m, mean total cost = 3891.138
#   height = 10.50 m, mean total cost = 4272.390
#   height = 11.00 m, mean total cost = 4691.134
#   height = 11.50 m, mean total cost = 5137.056
#   height = 12.00 m, mean total cost = 5601.179
# Round 2500000: best height 3.00 m, mean cost 677.878, r=751.127, separated=False
#
# Round 2600000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.652
#   height = 0.50 m, mean total cost = 2061.180
#   height = 1.00 m, mean total cost = 2029.057
#   height = 1.50 m, mean total cost = 1459.391
#   height = 2.00 m, mean total cost = 924.373
#   height = 2.50 m, mean total cost = 713.691
#   height = 3.00 m, mean total cost = 677.766
#   height = 3.50 m, mean total cost = 720.041
#   height = 4.00 m, mean total cost = 816.475
#   height = 4.50 m, mean total cost = 946.431
#   height = 5.00 m, mean total cost = 1102.697
#   height = 5.50 m, mean total cost = 1289.475
#   height = 6.00 m, mean total cost = 1500.173
#   height = 6.50 m, mean total cost = 1744.745
#   height = 7.00 m, mean total cost = 2004.153
#   height = 7.50 m, mean total cost = 2277.225
#   height = 8.00 m, mean total cost = 2563.387
#   height = 8.50 m, mean total cost = 2874.629
#   height = 9.00 m, mean total cost = 3195.902
#   height = 9.50 m, mean total cost = 3535.699
#   height = 10.00 m, mean total cost = 3891.051
#   height = 10.50 m, mean total cost = 4272.316
#   height = 11.00 m, mean total cost = 4691.068
#   height = 11.50 m, mean total cost = 5136.987
#   height = 12.00 m, mean total cost = 5601.117
# Round 2600000: best height 3.00 m, mean cost 677.766, r=737.335, separated=False
#
# Round 2700000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.936
#   height = 0.50 m, mean total cost = 2061.464
#   height = 1.00 m, mean total cost = 2029.341
#   height = 1.50 m, mean total cost = 1459.687
#   height = 2.00 m, mean total cost = 924.653
#   height = 2.50 m, mean total cost = 713.975
#   height = 3.00 m, mean total cost = 678.080
#   height = 3.50 m, mean total cost = 720.344
#   height = 4.00 m, mean total cost = 816.768
#   height = 4.50 m, mean total cost = 946.680
#   height = 5.00 m, mean total cost = 1102.913
#   height = 5.50 m, mean total cost = 1289.665
#   height = 6.00 m, mean total cost = 1500.356
#   height = 6.50 m, mean total cost = 1744.929
#   height = 7.00 m, mean total cost = 2004.325
#   height = 7.50 m, mean total cost = 2277.380
#   height = 8.00 m, mean total cost = 2563.528
#   height = 8.50 m, mean total cost = 2874.752
#   height = 9.00 m, mean total cost = 3196.011
#   height = 9.50 m, mean total cost = 3535.788
#   height = 10.00 m, mean total cost = 3891.135
#   height = 10.50 m, mean total cost = 4272.389
#   height = 11.00 m, mean total cost = 4691.144
#   height = 11.50 m, mean total cost = 5137.063
#   height = 12.00 m, mean total cost = 5601.198
# Round 2700000: best height 3.00 m, mean cost 678.080, r=724.300, separated=False
#
# Round 2800000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.959
#   height = 0.50 m, mean total cost = 2061.487
#   height = 1.00 m, mean total cost = 2029.359
#   height = 1.50 m, mean total cost = 1459.699
#   height = 2.00 m, mean total cost = 924.686
#   height = 2.50 m, mean total cost = 714.026
#   height = 3.00 m, mean total cost = 678.131
#   height = 3.50 m, mean total cost = 720.412
#   height = 4.00 m, mean total cost = 816.824
#   height = 4.50 m, mean total cost = 946.732
#   height = 5.00 m, mean total cost = 1102.980
#   height = 5.50 m, mean total cost = 1289.728
#   height = 6.00 m, mean total cost = 1500.421
#   height = 6.50 m, mean total cost = 1744.984
#   height = 7.00 m, mean total cost = 2004.375
#   height = 7.50 m, mean total cost = 2277.432
#   height = 8.00 m, mean total cost = 2563.581
#   height = 8.50 m, mean total cost = 2874.814
#   height = 9.00 m, mean total cost = 3196.070
#   height = 9.50 m, mean total cost = 3535.850
#   height = 10.00 m, mean total cost = 3891.197
#   height = 10.50 m, mean total cost = 4272.467
#   height = 11.00 m, mean total cost = 4691.233
#   height = 11.50 m, mean total cost = 5137.159
#   height = 12.00 m, mean total cost = 5601.308
# Round 2800000: best height 3.00 m, mean cost 678.131, r=711.957, separated=False
#
# Round 2900000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.100
#   height = 0.50 m, mean total cost = 2061.628
#   height = 1.00 m, mean total cost = 2029.507
#   height = 1.50 m, mean total cost = 1459.890
#   height = 2.00 m, mean total cost = 924.805
#   height = 2.50 m, mean total cost = 714.073
#   height = 3.00 m, mean total cost = 678.172
#   height = 3.50 m, mean total cost = 720.444
#   height = 4.00 m, mean total cost = 816.858
#   height = 4.50 m, mean total cost = 946.752
#   height = 5.00 m, mean total cost = 1102.988
#   height = 5.50 m, mean total cost = 1289.722
#   height = 6.00 m, mean total cost = 1500.422
#   height = 6.50 m, mean total cost = 1744.983
#   height = 7.00 m, mean total cost = 2004.367
#   height = 7.50 m, mean total cost = 2277.410
#   height = 8.00 m, mean total cost = 2563.561
#   height = 8.50 m, mean total cost = 2874.778
#   height = 9.00 m, mean total cost = 3196.051
#   height = 9.50 m, mean total cost = 3535.824
#   height = 10.00 m, mean total cost = 3891.169
#   height = 10.50 m, mean total cost = 4272.443
#   height = 11.00 m, mean total cost = 4691.207
#   height = 11.50 m, mean total cost = 5137.149
#   height = 12.00 m, mean total cost = 5601.313
# Round 2900000: best height 3.00 m, mean cost 678.172, r=700.244, separated=False
#
# Round 3000000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.919
#   height = 0.50 m, mean total cost = 2061.447
#   height = 1.00 m, mean total cost = 2029.313
#   height = 1.50 m, mean total cost = 1459.689
#   height = 2.00 m, mean total cost = 924.665
#   height = 2.50 m, mean total cost = 713.971
#   height = 3.00 m, mean total cost = 678.073
#   height = 3.50 m, mean total cost = 720.347
#   height = 4.00 m, mean total cost = 816.757
#   height = 4.50 m, mean total cost = 946.656
#   height = 5.00 m, mean total cost = 1102.895
#   height = 5.50 m, mean total cost = 1289.636
#   height = 6.00 m, mean total cost = 1500.331
#   height = 6.50 m, mean total cost = 1744.896
#   height = 7.00 m, mean total cost = 2004.287
#   height = 7.50 m, mean total cost = 2277.332
#   height = 8.00 m, mean total cost = 2563.493
#   height = 8.50 m, mean total cost = 2874.713
#   height = 9.00 m, mean total cost = 3195.982
#   height = 9.50 m, mean total cost = 3535.750
#   height = 10.00 m, mean total cost = 3891.103
#   height = 10.50 m, mean total cost = 4272.374
#   height = 11.00 m, mean total cost = 4691.141
#   height = 11.50 m, mean total cost = 5137.090
#   height = 12.00 m, mean total cost = 5601.259
# Round 3000000: best height 3.00 m, mean cost 678.073, r=689.111, separated=False
#
# Round 3100000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.541
#   height = 0.50 m, mean total cost = 2061.069
#   height = 1.00 m, mean total cost = 2028.928
#   height = 1.50 m, mean total cost = 1459.284
#   height = 2.00 m, mean total cost = 924.269
#   height = 2.50 m, mean total cost = 713.621
#   height = 3.00 m, mean total cost = 677.759
#   height = 3.50 m, mean total cost = 720.051
#   height = 4.00 m, mean total cost = 816.463
#   height = 4.50 m, mean total cost = 946.382
#   height = 5.00 m, mean total cost = 1102.662
#   height = 5.50 m, mean total cost = 1289.412
#   height = 6.00 m, mean total cost = 1500.118
#   height = 6.50 m, mean total cost = 1744.696
#   height = 7.00 m, mean total cost = 2004.103
#   height = 7.50 m, mean total cost = 2277.154
#   height = 8.00 m, mean total cost = 2563.331
#   height = 8.50 m, mean total cost = 2874.552
#   height = 9.00 m, mean total cost = 3195.830
#   height = 9.50 m, mean total cost = 3535.603
#   height = 10.00 m, mean total cost = 3890.963
#   height = 10.50 m, mean total cost = 4272.240
#   height = 11.00 m, mean total cost = 4691.015
#   height = 11.50 m, mean total cost = 5136.958
#   height = 12.00 m, mean total cost = 5601.131
# Round 3100000: best height 3.00 m, mean cost 677.759, r=678.510, separated=False
#
# Round 3200000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.886
#   height = 0.50 m, mean total cost = 2061.414
#   height = 1.00 m, mean total cost = 2029.278
#   height = 1.50 m, mean total cost = 1459.639
#   height = 2.00 m, mean total cost = 924.618
#   height = 2.50 m, mean total cost = 713.971
#   height = 3.00 m, mean total cost = 678.087
#   height = 3.50 m, mean total cost = 720.347
#   height = 4.00 m, mean total cost = 816.731
#   height = 4.50 m, mean total cost = 946.641
#   height = 5.00 m, mean total cost = 1102.910
#   height = 5.50 m, mean total cost = 1289.672
#   height = 6.00 m, mean total cost = 1500.359
#   height = 6.50 m, mean total cost = 1744.925
#   height = 7.00 m, mean total cost = 2004.324
#   height = 7.50 m, mean total cost = 2277.362
#   height = 8.00 m, mean total cost = 2563.530
#   height = 8.50 m, mean total cost = 2874.729
#   height = 9.00 m, mean total cost = 3195.987
#   height = 9.50 m, mean total cost = 3535.746
#   height = 10.00 m, mean total cost = 3891.102
#   height = 10.50 m, mean total cost = 4272.366
#   height = 11.00 m, mean total cost = 4691.127
#   height = 11.50 m, mean total cost = 5137.059
#   height = 12.00 m, mean total cost = 5601.227
# Round 3200000: best height 3.00 m, mean cost 678.087, r=668.400, separated=False
#
# Round 3300000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.882
#   height = 0.50 m, mean total cost = 2061.410
#   height = 1.00 m, mean total cost = 2029.286
#   height = 1.50 m, mean total cost = 1459.665
#   height = 2.00 m, mean total cost = 924.589
#   height = 2.50 m, mean total cost = 713.913
#   height = 3.00 m, mean total cost = 678.003
#   height = 3.50 m, mean total cost = 720.237
#   height = 4.00 m, mean total cost = 816.611
#   height = 4.50 m, mean total cost = 946.515
#   height = 5.00 m, mean total cost = 1102.771
#   height = 5.50 m, mean total cost = 1289.544
#   height = 6.00 m, mean total cost = 1500.226
#   height = 6.50 m, mean total cost = 1744.791
#   height = 7.00 m, mean total cost = 2004.179
#   height = 7.50 m, mean total cost = 2277.203
#   height = 8.00 m, mean total cost = 2563.374
#   height = 8.50 m, mean total cost = 2874.575
#   height = 9.00 m, mean total cost = 3195.834
#   height = 9.50 m, mean total cost = 3535.600
#   height = 10.00 m, mean total cost = 3890.952
#   height = 10.50 m, mean total cost = 4272.221
#   height = 11.00 m, mean total cost = 4690.998
#   height = 11.50 m, mean total cost = 5136.929
#   height = 12.00 m, mean total cost = 5601.104
# Round 3300000: best height 3.00 m, mean cost 678.003, r=658.744, separated=False
#
# Round 3400000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.832
#   height = 0.50 m, mean total cost = 2061.360
#   height = 1.00 m, mean total cost = 2029.228
#   height = 1.50 m, mean total cost = 1459.609
#   height = 2.00 m, mean total cost = 924.560
#   height = 2.50 m, mean total cost = 713.886
#   height = 3.00 m, mean total cost = 677.967
#   height = 3.50 m, mean total cost = 720.210
#   height = 4.00 m, mean total cost = 816.598
#   height = 4.50 m, mean total cost = 946.498
#   height = 5.00 m, mean total cost = 1102.758
#   height = 5.50 m, mean total cost = 1289.526
#   height = 6.00 m, mean total cost = 1500.193
#   height = 6.50 m, mean total cost = 1744.756
#   height = 7.00 m, mean total cost = 2004.141
#   height = 7.50 m, mean total cost = 2277.161
#   height = 8.00 m, mean total cost = 2563.332
#   height = 8.50 m, mean total cost = 2874.521
#   height = 9.00 m, mean total cost = 3195.800
#   height = 9.50 m, mean total cost = 3535.569
#   height = 10.00 m, mean total cost = 3890.930
#   height = 10.50 m, mean total cost = 4272.197
#   height = 11.00 m, mean total cost = 4690.977
#   height = 11.50 m, mean total cost = 5136.906
#   height = 12.00 m, mean total cost = 5601.087
# Round 3400000: best height 3.00 m, mean cost 677.967, r=649.509, separated=False
#
# Round 3500000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.264
#   height = 0.50 m, mean total cost = 2061.792
#   height = 1.00 m, mean total cost = 2029.668
#   height = 1.50 m, mean total cost = 1460.039
#   height = 2.00 m, mean total cost = 924.998
#   height = 2.50 m, mean total cost = 714.331
#   height = 3.00 m, mean total cost = 678.402
#   height = 3.50 m, mean total cost = 720.636
#   height = 4.00 m, mean total cost = 816.988
#   height = 4.50 m, mean total cost = 946.859
#   height = 5.00 m, mean total cost = 1103.093
#   height = 5.50 m, mean total cost = 1289.830
#   height = 6.00 m, mean total cost = 1500.479
#   height = 6.50 m, mean total cost = 1745.036
#   height = 7.00 m, mean total cost = 2004.404
#   height = 7.50 m, mean total cost = 2277.411
#   height = 8.00 m, mean total cost = 2563.560
#   height = 8.50 m, mean total cost = 2874.729
#   height = 9.00 m, mean total cost = 3195.991
#   height = 9.50 m, mean total cost = 3535.751
#   height = 10.00 m, mean total cost = 3891.103
#   height = 10.50 m, mean total cost = 4272.355
#   height = 11.00 m, mean total cost = 4691.125
#   height = 11.50 m, mean total cost = 5137.047
#   height = 12.00 m, mean total cost = 5601.219
# Round 3500000: best height 3.00 m, mean cost 678.402, r=640.664, separated=False
#
# Round 3600000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.148
#   height = 0.50 m, mean total cost = 2061.676
#   height = 1.00 m, mean total cost = 2029.543
#   height = 1.50 m, mean total cost = 1459.884
#   height = 2.00 m, mean total cost = 924.891
#   height = 2.50 m, mean total cost = 714.288
#   height = 3.00 m, mean total cost = 678.375
#   height = 3.50 m, mean total cost = 720.623
#   height = 4.00 m, mean total cost = 816.969
#   height = 4.50 m, mean total cost = 946.853
#   height = 5.00 m, mean total cost = 1103.109
#   height = 5.50 m, mean total cost = 1289.829
#   height = 6.00 m, mean total cost = 1500.474
#   height = 6.50 m, mean total cost = 1745.026
#   height = 7.00 m, mean total cost = 2004.407
#   height = 7.50 m, mean total cost = 2277.426
#   height = 8.00 m, mean total cost = 2563.577
#   height = 8.50 m, mean total cost = 2874.739
#   height = 9.00 m, mean total cost = 3196.001
#   height = 9.50 m, mean total cost = 3535.769
#   height = 10.00 m, mean total cost = 3891.121
#   height = 10.50 m, mean total cost = 4272.380
#   height = 11.00 m, mean total cost = 4691.157
#   height = 11.50 m, mean total cost = 5137.081
#   height = 12.00 m, mean total cost = 5601.261
# Round 3600000: best height 3.00 m, mean cost 678.375, r=632.184, separated=False
#
# Round 3700000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2043.142
#   height = 0.50 m, mean total cost = 2061.670
#   height = 1.00 m, mean total cost = 2029.533
#   height = 1.50 m, mean total cost = 1459.866
#   height = 2.00 m, mean total cost = 924.900
#   height = 2.50 m, mean total cost = 714.313
#   height = 3.00 m, mean total cost = 678.406
#   height = 3.50 m, mean total cost = 720.657
#   height = 4.00 m, mean total cost = 817.001
#   height = 4.50 m, mean total cost = 946.893
#   height = 5.00 m, mean total cost = 1103.152
#   height = 5.50 m, mean total cost = 1289.858
#   height = 6.00 m, mean total cost = 1500.511
#   height = 6.50 m, mean total cost = 1745.055
#   height = 7.00 m, mean total cost = 2004.442
#   height = 7.50 m, mean total cost = 2277.465
#   height = 8.00 m, mean total cost = 2563.601
#   height = 8.50 m, mean total cost = 2874.768
#   height = 9.00 m, mean total cost = 3196.043
#   height = 9.50 m, mean total cost = 3535.807
#   height = 10.00 m, mean total cost = 3891.150
#   height = 10.50 m, mean total cost = 4272.392
#   height = 11.00 m, mean total cost = 4691.166
#   height = 11.50 m, mean total cost = 5137.092
#   height = 12.00 m, mean total cost = 5601.286
# Round 3700000: best height 3.00 m, mean cost 678.406, r=624.042, separated=False
#
# Round 3800000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.916
#   height = 0.50 m, mean total cost = 2061.444
#   height = 1.00 m, mean total cost = 2029.294
#   height = 1.50 m, mean total cost = 1459.636
#   height = 2.00 m, mean total cost = 924.698
#   height = 2.50 m, mean total cost = 714.121
#   height = 3.00 m, mean total cost = 678.223
#   height = 3.50 m, mean total cost = 720.467
#   height = 4.00 m, mean total cost = 816.809
#   height = 4.50 m, mean total cost = 946.705
#   height = 5.00 m, mean total cost = 1102.968
#   height = 5.50 m, mean total cost = 1289.682
#   height = 6.00 m, mean total cost = 1500.353
#   height = 6.50 m, mean total cost = 1744.911
#   height = 7.00 m, mean total cost = 2004.310
#   height = 7.50 m, mean total cost = 2277.346
#   height = 8.00 m, mean total cost = 2563.483
#   height = 8.50 m, mean total cost = 2874.660
#   height = 9.00 m, mean total cost = 3195.944
#   height = 9.50 m, mean total cost = 3535.710
#   height = 10.00 m, mean total cost = 3891.065
#   height = 10.50 m, mean total cost = 4272.313
#   height = 11.00 m, mean total cost = 4691.098
#   height = 11.50 m, mean total cost = 5137.024
#   height = 12.00 m, mean total cost = 5601.234
# Round 3800000: best height 3.00 m, mean cost 678.223, r=616.218, separated=False
#
# Round 3900000 – mean total cost per candidate height:
#   height = 0.00 m, mean total cost = 2042.756
#   height = 0.50 m, mean total cost = 2061.284
#   height = 1.00 m, mean total cost = 2029.138
#   height = 1.50 m, mean total cost = 1459.473
#   height = 2.00 m, mean total cost = 924.542
#   height = 2.50 m, mean total cost = 713.963
#   height = 3.00 m, mean total cost = 678.056
#   height = 3.50 m, mean total cost = 720.317
#   height = 4.00 m, mean total cost = 816.663
#   height = 4.50 m, mean total cost = 946.546
#   height = 5.00 m, mean total cost = 1102.813
#   height = 5.50 m, mean total cost = 1289.525
#   height = 6.00 m, mean total cost = 1500.195
#   height = 6.50 m, mean total cost = 1744.753
#   height = 7.00 m, mean total cost = 2004.138
#   height = 7.50 m, mean total cost = 2277.178
#   height = 8.00 m, mean total cost = 2563.315
#   height = 8.50 m, mean total cost = 2874.489
#   height = 9.00 m, mean total cost = 3195.768
#   height = 9.50 m, mean total cost = 3535.541
#   height = 10.00 m, mean total cost = 3890.905
#   height = 10.50 m, mean total cost = 4272.153
#   height = 11.00 m, mean total cost = 4690.947
#   height = 11.50 m, mean total cost = 5136.883
#   height = 12.00 m, mean total cost = 5601.107
# Round 3900000: best height 3.00 m, mean cost 678.056, r=608.691, separated=False

# %%
import math
import numpy as np
delta=0.05
# --- Helper: required samples for a given assumed gap ---
def required_samples_for_gap(
    gap: float,
    D_max_total: float,
    num_cands: int,
    delta: float,
    S_max: int = 10**16,
) -> int:
    """
    Solve for S such that 2 * r(S) <= gap, where
    r(S) = D_max_total * sqrt( log(2 * K * S * (S + 1) / delta) / (2 S) ).
    """
    target = gap / 2.0  # need r(S) <= gap/2

    def radius(S: int) -> float:
        log_term = math.log(
            (2.0 * num_cands * S * (S + 1)) / max(delta, 1e-16)
        )
        return D_max_total * math.sqrt(log_term / (2.0 * S))

    # If S=1 already enough (unlikely), return 1
    if radius(1) <= target:
        return 1

    # Exponential search to bracket S
    low, high = 1, 1
    while high < S_max and radius(high) > target:
        low = high
        high *= 2

    if high >= S_max and radius(high) > target:
        # Could not find S within S_max
        return S_max

    # Binary search between low and high
    while low + 1 < high:
        mid = (low + high) // 2
        if radius(mid) <= target:
            high = mid
        else:
            low = mid

    return high


# --- Compute D_max_total and num_cands from your existing objects ---

# damage_costs: full damage curve (million EUR)
# years_range: (start_year, end_year)
# candidate_indices: indices of surviving heights
# delta: your bandit delta

start_year, end_year = years_range
n_years = end_year - start_year + 1
d_max = float(np.max(damage_costs))
D_max_total = n_years * d_max
num_cands = len(candidate_indices)

# --- Assume the gap between best & second best is about 30 ---
gap_assumed = 30.0

S_req = required_samples_for_gap(
    gap=gap_assumed,
    D_max_total=D_max_total,
    num_cands=num_cands,
    delta=delta,
)

print(f"Assumed gap = {gap_assumed:.1f}")
print(f"Approx. total samples needed for separation: {S_req}")
# Out:
# Assumed gap = 30.0
# Approx. total samples needed for separation: 9095155553

# %%
((9095155553/10000000)*(9*60))/(3600*24)
# Out:
# 5.684472220625
